# %% [markdown]
# <h1><font color="#113D68" size=6>TINTOlib: Converting Tidy Data into Image for 2-Dimensional Convolutional Neural Networks</font></h1>
#
# <h1><font color="#113D68" size=5>Template Classification Machine Learning problem with a Hibryd Networks (CNN+MLP)</font></h1>
#
# <br><br>
# <div style="text-align: right">
# <font color="#113D68" size=3>Manuel Castillo-Cara</font><br>
# <font color="#113D68" size=3>Raúl García-Castro</font><br>
#
# </div>
#
# ---

# %% [markdown]
# ---
#
# <a id="indice"></a>
# <h2><font color="#004D7F" size=5>Index</font></h2>
#
# * [0. Context](#section0)
# * [1. Description](#section1)
#     * [1.1. Main Features](#section11)
#     * [1.2. Citation](#section12)
#     * [1.3. Documentation and License](#section13)
# * [2. Libraries](#section2)
#     * [2.1. System setup](#section21)
#     * [2.2. Invoke the libraries](#section22)
# * [3. Data processing](#section3)
#     * [3.1. TINTOlib methods](#section31)
#     * [3.2. Read the dataset](#section32)
#     * [3.3. Generate images](#section33)
#     * [3.4. Read images](#section34)
#     * [3.5. Mix images and tidy data](#section35)
# * [4. Pre-modelling phase](#section4)
#     * [4.1. Data curation](#section41)
#     * [4.2. One-hot encoding](#section42)
# * [5. Modelling hybrid network](#section5)
#     * [5.1. FFNN for tabular data](#section51)
#     * [5.2. CNN for TINTOlib images](#section52)
#     * [5.3. Concatenate branches](#section53)
#     * [5.4. Metrics](#section54)
#     * [5.5. Compile and fit](#section55)
# * [6. Results](#section6)
#     * [6.1. Train/Validation representation](#section61)
#     * [6.2. Validation/Test evaluation](#section62)

# %% [markdown]
# ---
# <a id="section0"></a>
# # <font color="#004D7F" size=6> 0. Context</font>

# %% [markdown]
# This is a tutorial on how to read the images created by TINTOlib and pass them to a very simple pretrained Convolutional Neural Network (CNN). The images must already be created by the TINTOlib software. See the documentation in GITHUB for how to create the images from tabular data.
#
# Remember that when using CNN you can set the training to be done with GPUs to improve performance.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# You can see all information about TINTOlib code in [GitHub](https://github.com/oeg-upm/TINTOlib)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# You can see all information about TINTOlib documentation in [PyPI](https://tintolib.readthedocs.io/en/latest/installation.html)

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section1"></a>
# # <font color="#004D7F" size=6> 1. Description</font>

# %% [markdown]
# The growing interest in the use of algorithms-based machine learning for predictive tasks has generated a large and diverse development of algorithms. However, it is widely known that not all of these algorithms are adapted to efficient solutions in certain tidy data format datasets. For this reason, novel techniques are currently being developed to convert tidy data into images with the aim of using Convolutional Neural Networks (CNNs). TINTOlib offers the opportunity to convert tidy data into images through several techniques: TINTO, IGTD, REFINED, SuperTML, BarGraph, DistanceMatrix and Combination.

# %% [markdown]
# ---
# <a id="section11"></a>
# # <font color="#004D7F" size=5> 1.1. Main Features</font>

# %% [markdown]
# - Supports all CSV data in **[Tidy Data](https://www.jstatsoft.org/article/view/v059i10)** format.
# - For now, the algorithm converts tabular data for binary and multi-class classification problems into machine learning.
# - Input data formats:
#     - **Tabular files**: The input data could be in **[CSV](https://en.wikipedia.org/wiki/Comma-separated_values)**, taking into account the **[Tidy Data](https://www.jstatsoft.org/article/view/v059i10)** format.
#     - **Dataframe***: The input data could be in **[Pandas Dataframe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html)**, taking into account the **[Tidy Data](https://www.jstatsoft.org/article/view/v059i10)** format.
#     - **Tidy Data**: The **target** (variable to be predicted) should be set as the last column of the dataset. Therefore, the first columns will be the features.
#     - All data must be in numerical form. TINTOlib does not accept data in string or any other non-numeric format.
# - Runs on **Linux**, **Windows** and **macOS** systems.
# - Compatible with **[Python](https://www.python.org/)** 3.7 or higher.

# %% [markdown]
# ---
# <a id="section12"></a>
# # <font color="#004D7F" size=5> 1.2. Citation</font>

# %% [markdown]
# **TINTOlib** is an python library that makes **Synthetic Images** from [Tidy Data](https://www.jstatsoft.org/article/view/v059i10) (also knows as **Tabular Data**).
#
# **Citing TINTO**: If you used TINTO in your work, please cite the **[SoftwareX](https://doi.org/10.1016/j.softx.2023.101391)**:
#
# ```bib
# @article{softwarex_TINTO,
#     title = {TINTO: Converting Tidy Data into Image for Classification
#             with 2-Dimensional Convolutional Neural Networks},
#     journal = {SoftwareX},
#     author = {Manuel Castillo-Cara and Reewos Talla-Chumpitaz and
#               Raúl García-Castro and Luis Orozco-Barbosa},
#     year = {2023},
#     pages = {101391},
#     issn = {2352-7110},
#     doi = {https://doi.org/10.1016/j.softx.2023.101391}
# }
# ```
#
# And use-case developed in **[INFFUS Paper](https://doi.org/10.1016/j.inffus.2022.10.011)**
#
# ```bib
# @article{inffus_TINTO,
#     title = {A novel deep learning approach using blurring image
#             techniques for Bluetooth-based indoor localisation},
#     journal = {Information Fusion},
#     author = {Reewos Talla-Chumpitaz and Manuel Castillo-Cara and
#               Luis Orozco-Barbosa and Raúl García-Castro},
#     volume = {91},
#     pages = {173-186},
#     year = {2023},
#     issn = {1566-2535},
#     doi = {https://doi.org/10.1016/j.inffus.2022.10.011}
# }
# ```

# %% [markdown]
# ---
# <a id="section13"></a>
# # <font color="#004D7F" size=5> 1.3. Documentation and License</font>

# %% [markdown]
# TINTOlib has a wide range of documentation on both GitHub and PiPY.
#
# Moreover, TINTOlib is free and open software with Apache 2.0 license.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# You can see all information about TINTOlib code in [GitHub](https://github.com/oeg-upm/TINTOlib)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# You can see all information about TINTOlib documentation in [PyPI](https://tintolib.readthedocs.io/en/latest/installation.html)

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section2"></a>
# # <font color="#004D7F" size=6> 2. Libraries</font>

# %% [markdown]
# ---
# <a id="section21"></a>
# # <font color="#004D7F" size=5> 2.1. System setup</font>

# %% [markdown]
# Before installing the libraries you must have the `mpi4py` package installed on the native (Linux) system. This link shows how to install it:
# - Link: [`mpi4py` in Linux](https://www.geeksforgeeks.org/how-to-install-python3-mpi4py-package-on-linux/)
#
# For example, in Linux:
#
# ```
#     sudo apt-get install python3
#     sudo apt install python3-pip
#     sudo apt install python3-mpi4py
# ```
#
# If you are in Windows, Mac or, also, Linux, you can install from PyPI if you want:
# ```
#     sudo pip3 install mpi4py
# ```

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# Note that you must **restart the kernel or the system** so that it can load the libraries.

# %% [markdown]
# Now, once you have installed `mpi4py` you can install the PyPI libraries and dependences.

# %%
# !pip install torchmetrics pytorch_lightning TINTOlib imblearn keras_preprocessing mpi4py pytorch-gradcam
# Out:
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: pytorch_lightning in /usr/local/lib/python3.10/dist-packages (2.1.3)
# Requirement already satisfied: TINTOlib in /usr/local/lib/python3.10/dist-packages (0.0.14)
# Requirement already satisfied: imblearn in /usr/local/lib/python3.10/dist-packages (0.0)
# Requirement already satisfied: keras_preprocessing in /usr/local/lib/python3.10/dist-packages (1.1.2)
# Requirement already satisfied: mpi4py in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: pytorch-gradcam in /usr/local/lib/python3.10/dist-packages (0.2.1)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.23.5)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (23.2)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.1.0+cu121)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (0.10.0)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2023.6.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.5.0)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (from imblearn) (0.10.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras_preprocessing) (1.16.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from pytorch-gradcam) (4.8.0.76)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.9.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (67.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (3.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->torchmetrics) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->torchmetrics) (1.3.0)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# Note that you must **restart the kernel** so that it can load the libraries.

# %% [markdown]
# ---
# <a id="section22"></a>
# # <font color="#004D7F" size=5> 2.2. Invoke the libraries</font>

# %% [markdown]
# The first thing we need to do is to declare the libraries

# %%
import os
import pandas as pd
import numpy as np

np.random.seed(42)

from tqdm import tqdm
#import cv2
import gc
import matplotlib.pyplot as plt
#import openslide
#from openslide.deepzoom import DeepZoomGenerator
import tifffile as tifi
import sklearn
import tensorflow as tf
import seaborn as sns
from PIL import Image


from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score,mean_absolute_percentage_error
from sklearn.preprocessing import LabelEncoder

from keras_preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model

from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import vgg16, vgg19, resnet50, mobilenet, inception_resnet_v2, densenet, inception_v3, xception, nasnet, ResNet152V2
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, InputLayer, LayerNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import SGD, Adam, Adadelta, Adamax
from tensorflow.keras import layers, models, Model
from tensorflow.keras.losses import MeanAbsoluteError, MeanAbsolutePercentageError
from tensorflow.keras.layers import Input, Activation,MaxPooling2D, concatenate, Concatenate, AveragePooling2D
from tensorflow.keras.utils import to_categorical

from imblearn.over_sampling import RandomOverSampler

#Models of TINTOlib
from TINTOlib.tinto import TINTO
from TINTOlib.supertml import SuperTML
from TINTOlib.igtd import IGTD
from TINTOlib.refined import REFINED
from TINTOlib.barGraph import BarGraph
from TINTOlib.distanceMatrix import DistanceMatrix
from TINTOlib.combination import Combination
import TINTOlib.utils

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section3"></a>
# # <font color="#004D7F" size=6> 3. Data processing</font>

# %% [markdown]
# The first thing to do is to read all the images created by TINTO. TINTO creates a folder which contains subfolders corresponding to each target that has the problem. Each image corresponds to a sample of the original dataset.

# %% [markdown]
# ---
# <a id="section31"></a>
# # <font color="#004D7F" size=5> 3.1. TINTOlib methods</font>

# %% [markdown]
# We prepare the declaration of the classes with the TINTOlib method we want to transform. Note that TINTOlib has several methods and we will have to choose one of them since each method generates different images.
#
# In addition, we establish the paths where the dataset is located and also the folder where the images will be created.

# %%
pixels = 20

# %%
#Select the model and the parameters
problem_type = "supervised"
#image_model = REFINED(problem= problem_type,hcIterations=5)
image_model = TINTO(problem= problem_type,blur=False,pixels=pixels)
#image_model = IGTD(problem= problem_type)
#image_model = BarGraph(problem= problem_type)
#image_model = DistanceMatrix(problem= problem_type)
#image_model = Combination(problem= problem_type)

#Define the dataset path and the folder where the images will be saved
dataset_path = "/content/drive/MyDrive/Máster UNED/TFM/Datasets/Data_for_UCI_named.csv"
images_folder = "hybridclassification"

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# You can see all TINTOlib method in the [PyPI documentation](https://tintolib.readthedocs.io/en/latest/installation.html)

# %% [markdown]
# ---
# <a id="section32"></a>
# # <font color="#004D7F" size=5> 3.2. Read the dataset</font>

# %% [markdown]
# In this part, we proceed to read the dataset according to the path specified above and also standardize the name that the target will have, in this case, it will be called `class`.

# %%
#Read CSV
df=pd.read_csv(dataset_path, delimiter=';')

df.pop('stab')

column_to_move = df.pop('stabf')
df['stabf'] = column_to_move

class_col = df.iloc[:,-1]
df = df.iloc[: , :-1]
df['class'] = class_col
df
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4     class
# 0    -1.723086  0.650456  0.859578  0.887445  0.958034  unstable
# 1    -1.255012  0.413441  0.862414  0.562139  0.781760    stable
# 2    -0.920492  0.163041  0.766689  0.839444  0.109853  unstable
# 3    -0.997374  0.446209  0.976744  0.929381  0.362718  unstable
# 4    -0.554305  0.797110  0.455450  0.656947  0.820923  unstable
# ...        ...       ...       ...       ...       ...       ...
# 9995 -1.236256  0.601709  0.779642  0.813512  0.608385  unstable
# 9996 -1.733414  0.502079  0.567242  0.285880  0.366120    stable
# 9997 -1.975373  0.487838  0.986505  0.149286  0.145984    stable
# 9998 -0.898510  0.365246  0.587558  0.889118  0.818391  unstable
# 9999 -0.570329  0.073056  0.505441  0.378761  0.942631  unstable
#
# [10000 rows x 13 columns]

# %% [markdown]
# ---
# <a id="section33"></a>
# # <font color="#004D7F" size=5> 3.3. Generate images</font>

# %% [markdown]
# Now we can generate the images with the `generateImages()` generic function. Likewise, we create a dataset that will have the path of each of the samples with the corresponding image created for it.
#
# Note that each image is created based on a row, therefore, each numerical sample of the dataset will correspond to a particular image. In other words, we will have the same number of images as samples/rows.

# %%
#Generate the images
image_model.generateImages(df, images_folder)
img_paths = os.path.join(images_folder,problem_type+".csv")

print(img_paths)
# Out:
# hybridclassification/supervised.csv

# %% [markdown]
# ---
# <a id="section34"></a>
# # <font color="#004D7F" size=5> 3.4. Read Images</font>

# %% [markdown]
# Now, we read the created images

# %%
imgs = pd.read_csv(img_paths)

#imgs["images"]= images_folder + "\\" + imgs["images"]
imgs["images"]= images_folder + "/" + imgs["images"]

# %% [markdown]
# ---
# <a id="section35"></a>
# # <font color="#004D7F" size=5> 3.5. Mix images and tidy data</font>

# %% [markdown]
# Since we are going to use hybrid networks, i.e. create a model in which we join a CNN for the images and a MLP for the tabular data, we are going to join it in order to integrate all the data in our hybrid model.

# %%
# Select all the attributes to normalize
columns_to_normalize = df.columns[:-1]

# Normalize between 0 and 1
df_normalized = (df[columns_to_normalize] - df[columns_to_normalize].min()) / (df[columns_to_normalize].max() - df[columns_to_normalize].min())

# Combine the attributes and the label
df_normalized = pd.concat([df_normalized, df[df.columns[-1]]], axis=1)

df_normalized.head(8)
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  0.258801  0.271561  0.829616  0.976978  0.509244  0.811642  0.495075
# 1  0.926793  0.463424  0.268117  0.091471  0.813957  0.039894  0.084809
# 2  0.891799  0.878795  0.268005  0.075171  0.425652  0.528367  0.481864
# 3  0.022700  0.754704  0.419623  0.193715  0.556118  0.648372  0.040670
# 4  0.277230  0.748301  0.467747  0.985065  0.453830  0.582991  0.102655
# 5  0.684139  0.906251  0.345657  0.396602  0.664921  0.095182  0.886441
# 6  0.653709  0.343702  0.676782  0.875683  0.190299  0.923668  0.527457
# 7  0.679328  0.092528  0.549405  0.775856  0.383459  0.834050  0.542331
#
#          p4        g1        g2        g3        g4     class
# 0  0.184572  0.632098  0.852229  0.881531  0.955894  unstable
# 1  0.496642  0.382588  0.855215  0.539078  0.770323    stable
# 2  0.719670  0.118990  0.754440  0.831000  0.062980  unstable
# 3  0.668412  0.417084  0.975576  0.925677  0.329181  unstable
# 4  0.963811  0.786481  0.426782  0.638883  0.811553  unstable
# 5  0.065200  0.222947  0.029347  0.518808  0.442048    stable
# 6  0.950677  0.134621  0.366277  0.370546  0.343827  unstable
# 7  0.473995  0.338316  0.613913  0.718672  0.347948  unstable

# %% [markdown]
# Combine the images and tidy data in the same dataframe, split attributes and objective value

# %%
combined_dataset = pd.concat([imgs,df_normalized.iloc[:, :-1]],axis=1)

df_x = combined_dataset.drop("class",axis=1)
df_y = combined_dataset["class"]

print(df_y)
# Out:
# 0       unstable
# 1         stable
# 2       unstable
# 3       unstable
# 4       unstable
#           ...
# 9995    unstable
# 9996      stable
# 9997      stable
# 9998    unstable
# 9999    unstable
# Name: class, Length: 10000, dtype: object

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section4"></a>
# # <font color="#004D7F" size=6> 4. Pre-modelling phase</font>

# %% [markdown]
# Once the data is ready, we load it into memory with an iterator in order to pass it to the CNN.

# %% [markdown]
# ---
# <a id="section41"></a>
# # <font color="#004D7F" size=5> 4.1. Data curation</font>

# %% [markdown]
# Note that each method generates images of **different pixel size**. For example:
# - `TINTO` method has a parameter that you can specify the size in pixels which by default is 20.
# - Other parameters such as `Combined` generates the size automatically and you must obtain them from the _shape_ of the images.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# You can see all information about TINTOlib documentation in [PyPI](https://tintolib.readthedocs.io/en/latest/installation.html)

# %% [markdown]
# Split in train/test/validation.
#
# Note that the partitioning of the images is also performed, in addition to the tabular data.

# %%
label_encoder = LabelEncoder()
df_y = label_encoder.fit_transform(df_y)
df_y
# Out:
# array([1, 0, 1, ..., 0, 1, 1])

# %%
labels = label_encoder.classes_

for label, integer_value in zip(labels, range(len(labels))):
    print(f"Label: {label} -> Integer Value: {integer_value}")
# Out:
# Label: stable -> Integer Value: 0
# Label: unstable -> Integer Value: 1

# %%
import cv2
X_train, X_val, y_train, y_val = train_test_split(df_x, df_y, test_size = 0.40, random_state = 42,stratify=df_y)
#X_val, X_test, y_val, y_test = train_test_split(X_val, y_val, test_size = 0.50, random_state = 123,stratify=y_val)

X_train_num = X_train.drop("images",axis=1)
X_val_num = X_val.drop("images",axis=1)
#X_test_num = X_test.drop("images",axis=1)

"""X_train_img = np.array([cv2.imread(img) for img in X_train["images"]])
X_val_img = np.array([cv2.imread(img) for img in X_val["images"]])
X_test_img = np.array([cv2.imread(img) for img in X_test["images"]])"""

X_train_img = np.array([cv2.resize(cv2.imread(img),(pixels,pixels)) for img in X_train["images"]])
X_val_img = np.array([cv2.resize(cv2.imread(img),(pixels,pixels)) for img in X_val["images"]])
#X_test_img = np.array([cv2.resize(cv2.imread(img),(pixels,pixels)) for img in X_test["images"]])

n_class = df['class'].value_counts().count()
attributes = len(X_train_num.columns)

print("Image shape",X_train_img[0].shape)
print("Attributes",attributes)
print("Classes",n_class)
size=X_train_img[0].shape[0]
print("Image size (pixels):", pixels)
# Out:
# Image shape (20, 20, 3)
# Attributes 12
# Classes 2
# Image size (pixels): 20

# %% [markdown]
# ---
# <a id="section42"></a>
# # <font color="#004D7F" size=5> 4.2. One-hot encoding</font>

# %% [markdown]
# One-hot encoding **only** for multiclass machine learning problems

# %%
# y-1 because target is between [1,28] and not [0,27]
y_train_oh =  to_categorical(y_train-1,n_class)
y_val_oh = to_categorical(y_val-1,n_class)
#y_test_oh = to_categorical(y_test-1,n_class)

# %%
y_train
# Out:
# array([0, 1, 1, ..., 1, 0, 1])

# %%
y_train_oh
# Out:
# array([[0., 1.],
#        [1., 0.],
#        [1., 0.],
#        ...,
#        [1., 0.],
#        [0., 1.],
#        [1., 0.]], dtype=float32)

# %% [markdown]
# <a id="section5"></a>
# # <font color="#004D7F" size=6> 5. Modeling hybrid network</font>

# %% [markdown]
# Now we can start the CNN+MLP training. Before that we prepare the algorithm for reading data.
#
# In this example, 2 branch networks is created
# - 1º branch: FFNN for tabular data
# - 2º branch: CNN for TINTOlib images

# %% [markdown]
# ---
# <a id="section51"></a>
# # <font color="#004D7F" size=5> 5.1. FFNN for tabular data</font>
#
# This is an example of a simple FFNN for tabular data. Note that we are not looking for the optimization of the CNN but to show an example of TINTOlib execution.

# %%
shape = len(X_train_num.columns)


from keras.layers import AveragePooling2D, Concatenate

dropout = 0.3

filters_ffnn = [1024,512,256,128,64,32,16]

ff_inputs = Input(shape = (shape,))

# * START BRANCH 1
mlp_1 = Dense(1024, activation='relu')(ff_inputs)
mlp_1 = BatchNormalization()(mlp_1)
mlp_1 = Dropout(dropout)(mlp_1)

mlp_1 = Dense(512, activation='relu')(mlp_1)
mlp_1 = BatchNormalization()(mlp_1)
mlp_1 = Dropout(dropout)(mlp_1)

mlp_1 = Dense(256, activation='relu')(mlp_1)
mlp_1 = BatchNormalization()(mlp_1)
mlp_1 = Dropout(dropout)(mlp_1)

mlp_1 = Dense(128, activation='relu')(mlp_1)
mlp_1 = BatchNormalization()(mlp_1)
mlp_1 = Dropout(dropout)(mlp_1)

mlp_1 = Dense(64, activation='relu')(mlp_1)
mlp_1 = BatchNormalization()(mlp_1)
mlp_1 = Dropout(dropout)(mlp_1)

mlp_1 = Dense(32, activation='relu')(mlp_1)
mlp_1 = BatchNormalization()(mlp_1)
mlp_1 = Dropout(dropout)(mlp_1)

mlp_1 = Dense(16, activation='relu')(mlp_1)
mlp_1 = BatchNormalization()(mlp_1)
mlp_1 = Dropout(dropout)(mlp_1)

# * START BRANCH 2
mlp_2 = Dense(1024, activation='relu')(ff_inputs)
mlp_2 = BatchNormalization()(mlp_2)
mlp_2 = Dropout(dropout)(mlp_2)

mlp_2 = Dense(512, activation='relu')(mlp_2)
mlp_2 = BatchNormalization()(mlp_2)
mlp_2 = Dropout(dropout)(mlp_2)

mlp_2 = Dense(256, activation='relu')(mlp_2)
mlp_2 = BatchNormalization()(mlp_2)
mlp_2 = Dropout(dropout)(mlp_2)

mlp_2 = Dense(128, activation='relu')(mlp_2)
mlp_2 = BatchNormalization()(mlp_2)
mlp_2 = Dropout(dropout)(mlp_2)

mlp_2 = Dense(64, activation='relu')(mlp_2)
mlp_2 = BatchNormalization()(mlp_2)
mlp_2 = Dropout(dropout)(mlp_2)

mlp_2 = Dense(32, activation='relu')(mlp_2)
mlp_2 = BatchNormalization()(mlp_2)
mlp_2 = Dropout(dropout)(mlp_2)

mlp_2 = Dense(16, activation='relu')(mlp_2)
mlp_2 = BatchNormalization()(mlp_2)
mlp_2 = Dropout(dropout)(mlp_2)

merged_tabular = Concatenate(axis=1)([mlp_1, mlp_2])

ff_model = Model(inputs = ff_inputs, outputs = merged_tabular)

# * CNN

#input
input_shape = Input(shape=(pixels, pixels, 3))

#Start branch 1
tower_1 = Conv2D(16, (3,3), activation='relu',padding="same")(input_shape)
tower_1 = BatchNormalization()(tower_1)
tower_1 = Activation('relu')(tower_1)
tower_1 = MaxPooling2D(2,2)(tower_1)
tower_1 = Dropout(dropout)(tower_1)

tower_1 = Conv2D(32, (3,3), activation='relu',padding="same")(tower_1)
tower_1 = BatchNormalization()(tower_1)
tower_1 = Activation('relu')(tower_1)
tower_1 = MaxPooling2D(2,2)(tower_1)
tower_1 = Dropout(dropout)(tower_1)

tower_1 = Conv2D(64, (3,3), activation='relu',padding="same")(tower_1)
tower_1 = BatchNormalization()(tower_1)
tower_1 = Activation('relu')(tower_1)
tower_1 = MaxPooling2D(2,2)(tower_1)
tower_1 = Dropout(dropout)(tower_1)

tower_1 = Conv2D(64, (3,3), activation='relu',padding="same")(tower_1)
tower_1 = BatchNormalization()(tower_1)
tower_1 = Activation('relu')(tower_1)
tower_1 = MaxPooling2D(2,2)(tower_1)
tower_1 = Dropout(dropout)(tower_1)
#End branch 1

#Start branch 2
tower_2 = Conv2D(16, (5,5), activation='relu',padding="same")(input_shape)
tower_2 = BatchNormalization()(tower_2)
tower_2 = Activation('relu')(tower_2)
tower_2 = AveragePooling2D(2,2)(tower_2)
tower_2 = Dropout(dropout)(tower_2)

tower_2 = Conv2D(32, (5,5), activation='relu',padding="same")(tower_2)
tower_2 = BatchNormalization()(tower_2)
tower_2 = Activation('relu')(tower_2)
tower_2 = AveragePooling2D(2,2)(tower_2)
tower_2 = Dropout(dropout)(tower_2)

tower_2 = Conv2D(64, (5,5), activation='relu',padding="same")(tower_2)
tower_2 = BatchNormalization()(tower_2)
tower_2 = Activation('relu')(tower_2)
tower_2 = AveragePooling2D(2,2)(tower_2)
tower_2 = Dropout(dropout)(tower_2)

tower_2 = Conv2D(64, (5,5), activation='relu',padding="same")(tower_2)
tower_2 = BatchNormalization()(tower_2)
tower_2 = Activation('relu')(tower_2)
tower_2 = AveragePooling2D(2,2)(tower_2)
tower_2 = Dropout(dropout)(tower_2)
#End branch 2

#Concatenation of the 2 branches
merged = Concatenate(axis=1)([tower_1, tower_2])

#Flattening
merged = Flatten()(merged)

#Additional layers
out = Dense(512, activation='relu')(merged)
out = Dropout(dropout)(merged)
out = Dense(256, activation='sigmoid')(out)
out = Dropout(dropout)(out)
out = Dense(128, activation='sigmoid')(out)
out = Dropout(dropout)(out)
out = Dense(64, activation='sigmoid')(out)
out = Dropout(dropout)(out)
out = Dense(32, activation='sigmoid')(out)
out = Dropout(dropout)(out)


#out = Dense(n_class, activation='softmax')(out)

cnn_model = Model(input_shape, out)


combinedInput = concatenate([ff_model.output, cnn_model.output])
x = Dense(64, activation="relu")(combinedInput)
x = Dense(32, activation="relu")(x)
x = Dense(16, activation="relu")(x)
x = Dense(8, activation="relu")(x)
x = Dense(2, activation="softmax")(x)

modelX = Model(inputs=[ff_model.input, cnn_model.input], outputs=x)

#from keras.utils import plot_model
#model.summary()
#plot_model(model)#, to_file='convolutional_neural_network.png')

METRICS = [
    #tf.keras.metrics.TruePositives(name = 'tp'),
    #tf.keras.metrics.FalsePositives(name = 'fp'),
    #tf.keras.metrics.TrueNegatives(name = 'tn'),
    #tf.keras.metrics.FalseNegatives(name = 'fn'),
    tf.keras.metrics.BinaryAccuracy(name ='accuracy'),
    tf.keras.metrics.Precision(name = 'precision'),
    tf.keras.metrics.Recall(name = 'recall'),
    tf.keras.metrics.AUC(name = 'auc'),
    tf.keras.metrics.F1Score(name='f1_score')
]

#opt = Adam(learning_rate=1e-5)
opt = Adam()
modelX.compile(
    loss="binary_crossentropy",
    optimizer=opt,
    metrics = METRICS
)

# Define EarlyStopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)

epochs=500

model_history=modelX.fit(
    x=[X_train_num, X_train_img], y=y_train_oh,
    validation_data=([X_val_num, X_val_img], y_val_oh),
    epochs=epochs,
    batch_size=16,
    callbacks=[early_stopping]
)
#print(model_history.history.keys())

#modelX.save(images_folder+'/modelX_8.h5')

def true_dist(y_pred, y_true):
    return np.mean(np.sqrt(
        np.square(np.abs(y_pred[:,0] - y_true[:,0]))
        + np.square(np.abs(y_pred[:,1] - y_true[:,1]))
        ))
# Out:
# Epoch 1/500
# 375/375 [==============================] - 41s 69ms/step - loss: 0.5110 - accuracy: 0.7460 - precision: 0.7460 - recall: 0.7460 - auc: 0.8269 - f1_score: 0.7087 - val_loss: 0.8715 - val_accuracy: 0.6525 - val_precision: 0.6525 - val_recall: 0.6525 - val_auc: 0.7752 - val_f1_score: 0.4315
# Epoch 2/500
# 375/375 [==============================] - 29s 77ms/step - loss: 0.3785 - accuracy: 0.8267 - precision: 0.8267 - recall: 0.8267 - auc: 0.9102 - f1_score: 0.8138 - val_loss: 0.2495 - val_accuracy: 0.8957 - val_precision: 0.8957 - val_recall: 0.8957 - val_auc: 0.9659 - val_f1_score: 0.8858
# Epoch 3/500
# 375/375 [==============================] - 28s 75ms/step - loss: 0.3393 - accuracy: 0.8487 - precision: 0.8487 - recall: 0.8487 - auc: 0.9274 - f1_score: 0.8367 - val_loss: 0.2282 - val_accuracy: 0.9135 - val_precision: 0.9135 - val_recall: 0.9135 - val_auc: 0.9720 - val_f1_score: 0.9052
# Epoch 4/500
# 375/375 [==============================] - 30s 79ms/step - loss: 0.3292 - accuracy: 0.8513 - precision: 0.8513 - recall: 0.8513 - auc: 0.9312 - f1_score: 0.8377 - val_loss: 0.2065 - val_accuracy: 0.9187 - val_precision: 0.9187 - val_recall: 0.9187 - val_auc: 0.9766 - val_f1_score: 0.9105
# Epoch 5/500
# 375/375 [==============================] - 25s 66ms/step - loss: 0.3083 - accuracy: 0.8660 - precision: 0.8660 - recall: 0.8660 - auc: 0.9387 - f1_score: 0.8542 - val_loss: 0.2209 - val_accuracy: 0.9155 - val_precision: 0.9155 - val_recall: 0.9155 - val_auc: 0.
500
# 375/375 [==============================] - 27s 73ms/step - loss: 0.2208 - accuracy: 0.9067 - precision: 0.9067 - recall: 0.9067 - auc: 0.9671 - f1_score: 0.8986 - val_loss: 0.1615 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9856 - val_f1_score: 0.9328
# Epoch 47/500
# 375/375 [==============================] - 27s 72ms/step - loss: 0.2240 - accuracy: 0.9017 - precision: 0.9017 - recall: 0.9017 - auc: 0.9659 - f1_score: 0.8932 - val_loss: 0.1561 - val_accuracy: 0.9337 - val_precision: 0.9337 - val_recall: 0.9337 - val_auc: 0.9852 - val_f1_score: 0.9255
# Epoch 48/500
# 375/375 [==============================] - 25s 68ms/step - loss: 0.2263 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9658 - f1_score: 0.8963 - val_loss: 0.1469 - val_accuracy: 0.9488 - val_precision: 0.9488 - val_recall: 0.9488 - val_auc: 0.9895 - val_f1_score: 0.9445
# Epoch 49/500
# 375/375 [==============================] - 27s 72ms/step - loss: 0.2339 - accuracy: 0.8995 - precision: 0.8995 - recall: 0.8995 - auc: 0.9635 - f1_score: 0.8907 - val_loss: 0.1580 - val_accuracy: 0.9367 - val_precision: 0.9367 - val_recall: 0.9367 - val_auc: 0.9857 - val_f1_score: 0.9322
# Epoch 50/500
# 375/375 [==============================] - 27s 72ms/step - loss: 0.2313 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9644 - f1_score: 0.8968 - val_loss: 0.1423 - val_accuracy: 0.9485 - val_precision: 0.9485 - val_recall: 0.9485 - val_auc: 0.9897 - val_f1_score: 0.9439
# Epoch 51/500
# 375/375 [==============================] - 26s 69ms/step - loss: 0.2234 - accuracy: 0.9060 - precision: 0.9060 - recall: 0.9060 - auc: 0.9664 - f1_score: 0.8980 - val_loss: 0.1644 - val_accuracy: 0.9327 - val_precision: 0.9327 - val_recall: 0.9327 - val_auc: 0.9867 - val_f1_score: 0.9259
# Epoch 52/500
# 375/375 [==============================] - 27s 73ms/step - loss: 0.2222 - accuracy: 0.9072 - precision: 0.9072 - recall: 0.9072 - auc: 0.9662 - f1_score: 0.8994 - val_loss: 0.1595 - val_accuracy: 0.9355 - val_precision: 0.9355 - val_recall: 0.9355 - val_auc: 0.9858 - val_f1_score: 0.9307
# Epoch 53/500
# 375/375 [==============================] - 25s 65ms/step - loss: 0.2224 - accuracy: 0.9038 - precision: 0.9038 - recall: 0.9038 - auc: 0.9663 - f1_score: 0.8956 - val_loss: 0.1513 - val_accuracy: 0.9362 - val_precision: 0.9362 - val_recall: 0.9362 - val_auc: 0.9859 - val_f1_score: 0.9328
# Epoch 54/500
# 375/375 [==============================] - 27s 72ms/step - loss: 0.2254 - accuracy: 0.9033 - precision: 0.9033 - recall: 0.9033 - auc: 0.9656 - f1_score: 0.8957 - val_loss: 0.1578 - val_accuracy: 0.9470 - val_precision: 0.9470 - val_recall: 0.9470 - val_auc: 0.9897 - val_f1_score: 0.9426
# Epoch 55/500
# 375/375 [==============================] - 24s 65ms/step - loss: 0.2228 - accuracy: 0.9028 - precision: 0.9028 - recall: 0.9028 - auc: 0.9666 - f1_score: 0.8951 - val_loss: 0.1362 - val_accuracy: 0.9500 - val_precision: 0.9500 - val_recall: 0.9500 - val_auc: 0.9918 - val_f1_score: 0.9457
# Epoch 56/500
# 375/375 [==============================] - 29s 79ms/step - loss: 0.2159 - accuracy: 0.9110 - precision: 0.9110 - recall: 0.9110 - auc: 0.9682 - f1_score: 0.9034 - val_loss: 0.1472 - val_accuracy: 0.9445 - val_precision: 0.9445 - val_recall: 0.9445 - val_auc: 0.9901 - val_f1_score: 0.9397
# Epoch 57/500
# 375/375 [==============================] - 27s 72ms/step - loss: 0.
500
# 375/375 [==============================] - 28s 75ms/step - loss: 0.1659 - accuracy: 0.9290 - precision: 0.9290 - recall: 0.9290 - auc: 0.9798 - f1_score: 0.9233 - val_loss: 0.1297 - val_accuracy: 0.9513 - val_precision: 0.9513 - val_recall: 0.9513 - val_auc: 0.9897 - val_f1_score: 0.9467
# Epoch 152/500
# 375/375 [==============================] - 28s 75ms/step - loss: 0.1684 - accuracy: 0.9343 - precision: 0.9343 - recall: 0.9343 - auc: 0.9795 - f1_score: 0.9288 - val_loss: 0.1211 - val_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9905 - val_f1_score: 0.9494
# Epoch 153/500
# 375/375 [==============================] - 30s 81ms/step - loss: 0.1533 - accuracy: 0.9358 - precision: 0.9358 - recall: 0.9358 - auc: 0.9823 - f1_score: 0.9304 - val_loss: 0.1239 - val_accuracy: 0.9492 - val_precision: 0.9492 - val_recall: 0.9492 - val_auc: 0.9897 - val_f1_score: 0.9442
# Epoch 154/500
# 375/375 [==============================] - 29s 76ms/step - loss: 0.1577 - accuracy: 0.9347 - precision: 0.9347 - recall: 0.9347 - auc: 0.9816 - f1_score: 0.9289 - val_loss: 0.1217 - val_accuracy: 0.9500 - val_precision: 0.9500 - val_recall: 0.9500 - val_auc: 0.9917 - val_f1_score: 0.9449
# Epoch 155/500
# 375/375 [==============================] - 27s 71ms/step - loss: 0.1713 - accuracy: 0.9263 - precision: 0.9263 - recall: 0.9263 - auc: 0.9788 - f1_score: 0.9199 - val_loss: 0.1379 - val_accuracy: 0.9520 - val_precision: 0.9520 - val_recall: 0.9520 - val_auc: 0.9898 - val_f1_score: 0.9482
# Epoch 156/500
# 375/375 [==============================] - 30s 79ms/step - loss: 0.1555 - accuracy: 0.9387 - precision: 0.9387 - recall: 0.9387 - auc: 0.9813 - f1_score: 0.9334 - val_loss: 0.1202 - val_accuracy: 0.9505 - val_precision: 0.9505 - val_recall: 0.9505 - val_auc: 0.9904 - val_f1_score: 0.9463
# Epoch 157/500
# 375/375 [==============================] - 30s 81ms/step - loss: 0.1632 - accuracy: 0.9347 - precision: 0.9347 - recall: 0.9347 - auc: 0.9791 - f1_score: 0.9291 - val_loss: 0.1322 - val_accuracy: 0.9503 - val_precision: 0.9503 - val_recall: 0.9503 - val_auc: 0.9899 - val_f1_score: 0.9452
# Epoch 158/500
# 375/375 [==============================] - 27s 73ms/step - loss: 0.1613 - accuracy: 0.9348 - precision: 0.9348 - recall: 0.9348 - auc: 0.9797 - f1_score: 0.9290 - val_loss: 0.1304 - val_accuracy: 0.9465 - val_precision: 0.9465 - val_recall: 0.9465 - val_auc: 0.9897 - val_f1_score: 0.9408
# Epoch 159/500
# ...
# Epoch 229/500
# 375/375 [==============================] - 29s 78ms/step - loss: 0.1545 - accuracy: 0.9332 - precision: 0.9332 - recall: 0.9332 - auc: 0.9812 - f1_score: 0.9276 - val_loss: 0.1422 - val_accuracy: 0.9445 - val_precision: 0.9445 - val_recall: 0.9445 - val_auc: 0.9885 - val_f1_score: 0.9400
# Epoch 230/500
# 375/375 [==============================] - 31s 82ms/step - loss: 0.1568 - accuracy: 0.9370 - precision: 0.9370 - recall: 0.9370 - auc: 0.9811 - f1_score: 0.9319 - val_loss: 0.1444 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9863 - val_f1_score: 0.9379
# 375/375 [==============================] - 28s 74ms/step - loss: 0.1481 - accuracy: 0.9378 - precision: 0.9378 - recall: 0.9378 - auc: 0.9832 - f1_score: 0.9326 - val_loss: 0.1283 - val_accuracy: 0.9528 - val_precision: 0.9528 - val_recall: 0.9528 - val_auc: 0.9919 - val_f1_score: 0.9486
# Epoch 271/500
# 375/375 [==============================] - 31s 84ms/step - loss: 0.1385 - accuracy: 0.9485 - precision: 0.9485 - recall: 0.9485 - auc: 0.9841 - f1_score: 0.9439 - val_loss: 0.1142 - val_accuracy: 0.9523 - val_precision: 0.9523 - val_recall: 0.9523 - val_auc: 0.9898 - val_f1_score: 0.9476
# Epoch 272/500
# 375/375 [==============================] - 32s 85ms/step - loss: 0.1521 - accuracy: 0.9427 - precision: 0.9427 - recall: 0.9427 - auc: 0.9817 - f1_score: 0.9379 - val_loss: 0.1305 - val_accuracy: 0.9513 - val_precision: 0.9513 - val_recall: 0.9513 - val_auc: 0.9890 - val_f1_score: 0.9473
# Epoch 273/500
# 375/375 [==============================] - 30s 80ms/step - loss: 0.1425 - accuracy: 0.9392 - precision: 0.9392 - recall: 0.9392 - auc: 0.9845 - f1_score: 0.9341 - val_loss: 0.1255 - val_accuracy: 0.9463 - val_precision: 0.9463 - val_recall: 0.9463 - val_auc: 0.9897 - val_f1_score: 0.9409
# Epoch 274/500
# 375/375 [==============================] - 27s 73ms/step - loss: 0.1351 - accuracy: 0.9450 - precision: 0.9450 - recall: 0.9450 - auc: 0.9849 - f1_score: 0.9403 - val_loss: 0.1494 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9859 - val_f1_score: 0.9300
# Epoch 275/500
# 375/375 [==============================] - 33s 89ms/step - loss: 0.1521 - accuracy: 0.9403 - precision: 0.9403 - recall: 0.9403 - auc: 0.9819 - f1_score: 0.9352 - val_loss: 0.1305 - val_accuracy: 0.9423 - val_precision: 0.9423 - val_recall: 0.9423 - val_auc: 0.9884 - val_f1_score: 0.9358
# Epoch 276/500
# 375/375 [==============================] - 30s 80ms/step - loss: 0.1592 - accuracy: 0.9358 - precision: 0.9358 - recall: 0.9358 - auc: 0.9811 - f1_score: 0.9303 - val_loss: 0.1179 - val_accuracy: 0.9525 - val_precision: 0.9525 - val_recall: 0.9525 - val_auc: 0.9904 - val_f1_score: 0.9480
# Epoch 277/500
# 375/375 [==============================] - 30s 79ms/step - loss: 0.1541 - accuracy: 0.9347 - precision: 0.9347 - recall: 0.9347 - auc: 0.9821 - f1_score: 0.9288 - val_loss: 0.1139 - val_accuracy: 0.9550 - val_precision: 0.9550 - val_recall: 0.9550 - val_auc: 0.9910 - val_f1_score: 0.9510
# Epoch 278/500
# 375/375 [==============================] - 30s 80ms/step - loss: 0.1496 - accuracy: 0.9368 - precision: 0.9368 - recall: 0.9368 - auc: 0.9832 - f1_score: 0.9314 - val_loss: 0.1178 - val_accuracy: 0.9503 - val_precision: 0.9503 - val_recall: 0.9503 - val_auc: 0.9880 - val_f1_score: 0.9452
# Epoch 279/500
# 375/375 [==============================] - 31s 84ms/step - loss: 0.1369 - accuracy: 0.9453 - precision: 0.9453 - recall: 0.9453 - auc: 0.9852 - f1_score: 0.9407 - val_loss: 0.1146 - val_accuracy: 0.9567 - val_precision: 0.9567 - val_recall: 0.9567 - val_auc: 0.9921 - val_f1_score: 0.9529
# Epoch 280/500
# 375/375 [==============================] - 30s 80ms/step - loss: 0.1381 - accuracy: 0.9410 - precision: 0.9410 - recall: 0.9410 - auc: 0.9851 - f1_score: 0.9361 - val_loss: 0.1224 - val_accuracy: 0.9507 - val_precision: 0.9507 - val_recall: 0.9507 - val_auc: 0.9916 - val_f1_score: 0.9459

# %%
modelX.save('/content/drive/MyDrive/Máster UNED/TFM/Datasets/'+'uci_model_2x_hybrid_n.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from keras.utils import plot_model
modelX.summary()
plot_model(modelX)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 20, 20, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 20, 20, 16)           448       ['input_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 20, 20, 16)           1216      ['input_2[0][0]']
#
#  batch_normalization_14 (Ba  (None, 20, 20, 16)           64        ['conv2d[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 20, 20, 16)           64        ['conv2d_4[0][0]']
#  tchNormalization)
#
#  activation (Activation)     (None, 20, 20, 16)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_4 (Activation)   (None, 20, 20, 16)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  max_pooling2d (MaxPooling2  (None, 10, 10, 16)           0         ['activation[0][0]']
#  D)
#
#  average_pooling2d (Average  (None, 10, 10, 16)           0         ['activation_4[0][0]']
#  Pooling2D)
#
#  dropout_14 (Dropout)        (None, 10, 10, 16)           0         ['max_pooling2d[0][0]']
#
#  dropout_18 (Dropout)        (None, 10, 10, 16)           0         ['average_pooling2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 32)           4640      ['dropout_14[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 10, 10, 32)           12832     ['dropout_18[0][0]']
#
#  batch_normalization_15 (Ba  (None, 10, 10, 32)           128       ['conv2d_1[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 10, 10, 32)           128       ['conv2d_5[0][0]']
#  tchNormalization)
#
#  activation_1 (Activation)   (None, 10, 10, 32)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  activation_5 (Activation)   (None, 10, 10, 32)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 32)             0         ['activation_1[0][0]']
#  g2D)
#
#  average_pooling2d_1 (Avera  (None, 5, 5, 32)             0         ['activation_5[0][0]']
#  gePooling2D)
#
#  dense (Dense)               (None, 1024)                 31744     ['input_1[0][0]']
#
#  dense_7 (Dense)             (None, 1024)                 31744     ['input_1[0][0]']
#
#  dropout_15 (Dropout)        (None, 5, 5, 32)             0         ['max_pooling2d_1[0][0]']
#
#  dropout_19 (Dropout)        (None, 5, 5, 32)             0         ['average_pooling2d_1[0][0]']
#
#  batch_normalization (Batch  (None, 1024)                 4096      ['dense[0][0]']
#  Normalization)
#
#  batch_normalization_7 (Bat  (None, 1024)                 4096      ['dense_7[0][0]']
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 5, 5, 64)             18496     ['dropout_15[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 5, 5, 64)             51264     ['dropout_19[0][0]']
#
#  dropout (Dropout)           (None, 1024)                 0         ['batch_normalization[0][0]']
#
#  dropout_7 (Dropout)         (None, 1024)                 0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  batch_normalization_16 (Ba  (None, 5, 5, 64)             256       ['conv2d_2[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 5, 5, 64)             256       ['conv2d_6[0][0]']
#  tchNormalization)
#
#  dense_1 (Dense)             (None, 512)                  524800    ['dropout[0][0]']
#
#  dense_8 (Dense)             (None, 512)                  524800    ['dropout_7[0][0]']
#
#  activation_2 (Activation)   (None, 5, 5, 64)             0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  activation_6 (Activation)   (None, 5, 5, 64)             0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  batch_normalization_1 (Bat  (None, 512)                  2048      ['dense_1[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 512)                  2048      ['dense_8[0][0]']
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 64)             0         ['activation_2[0][0]']
#  g2D)
#
#  average_pooling2d_2 (Avera  (None, 2, 2, 64)             0         ['activation_6[0][0]']
#  gePooling2D)
#
#  dropout_1 (Dropout)         (None, 512)                  0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dropout_8 (Dropout)         (None, 512)                  0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_16 (Dropout)        (None, 2, 2, 64)             0         ['max_pooling2d_2[0][0]']
#
#  dropout_20 (Dropout)        (None, 2, 2, 64)             0         ['average_pooling2d_2[0][0]']
#
#  dense_2 (Dense)             (None, 256)                  131328    ['dropout_1[0][0]']
#
#  dense_9 (Dense)             (None, 256)                  131328    ['dropout_8[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 64)             36928     ['dropout_16[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 2, 2, 64)             102464    ['dropout_20[0][0]']
#
#  batch_normalization_2 (Bat  (None, 256)                  1024      ['dense_2[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 256)                  1024      ['dense_9[0][0]']
#  chNormalization)
#
#  batch_normalization_17 (Ba  (None, 2, 2, 64)             256       ['conv2d_3[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 2, 2, 64)             256       ['conv2d_7[0][0]']
#  tchNormalization)
#
#  dropout_2 (Dropout)         (None, 256)                  0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_9 (Dropout)         (None, 256)                  0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  activation_3 (Activation)   (None, 2, 2, 64)             0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_7 (Activation)   (None, 2, 2, 64)             0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  dense_3 (Dense)             (None, 128)                  32896     ['dropout_2[0][0]']
#
#  dense_10 (Dense)            (None, 128)                  32896     ['dropout_9[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 1, 1, 64)             0         ['activation_3[0][0]']
#  g2D)
#
#  average_pooling2d_3 (Avera  (None, 1, 1, 64)             0         ['activation_7[0][0]']
#  gePooling2D)
#
#  batch_normalization_3 (Bat  (None, 128)                  512       ['dense_3[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 128)                  512       ['dense_10[0][0]']
#  tchNormalization)
#
#  dropout_17 (Dropout)        (None, 1, 1, 64)             0         ['max_pooling2d_3[0][0]']
#
#  dropout_21 (Dropout)        (None, 1, 1, 64)             0         ['average_pooling2d_3[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_10 (Dropout)        (None, 128)                  0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  concatenate_1 (Concatenate  (None, 2, 1, 64)             0         ['dropout_17[0][0]',
#  )                                                                   'dropout_21[0][0]']
#
#  dense_4 (Dense)             (None, 64)                   8256      ['dropout_3[0][0]']
#
#  dense_11 (Dense)            (None, 64)                   8256      ['dropout_10[0][0]']
#
#  flatten (Flatten)           (None, 128)                  0         ['concatenate_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 64)                   256       ['dense_4[0][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, 64)                   256       ['dense_11[0][0]']
#  tchNormalization)
#
#  dropout_22 (Dropout)        (None, 128)                  0         ['flatten[0][0]']
#
#  dropout_4 (Dropout)         (None, 64)                   0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  dropout_11 (Dropout)        (None, 64)                   0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  dense_15 (Dense)            (None, 256)                  33024     ['dropout_22[0][0]']
#
#  dense_5 (Dense)             (None, 32)                   2080      ['dropout_4[0][0]']
#
#  dense_12 (Dense)            (None, 32)                   2080      ['dropout_11[0][0]']
#
#  dropout_23 (Dropout)        (None, 256)                  0         ['dense_15[0][0]']
#
#  batch_normalization_5 (Bat  (None, 32)                   128       ['dense_5[0][0]']
#  chNormalization)
#
#  batch_normalization_12 (Ba  (None, 32)                   128       ['dense_12[0][0]']
#  tchNormalization)
#
#  dense_16 (Dense)            (None, 128)                  32896     ['dropout_23[0][0]']
#
#  dropout_5 (Dropout)         (None, 32)                   0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_12 (Dropout)        (None, 32)                   0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  dropout_24 (Dropout)        (None, 128)                  0         ['dense_16[0][0]']
#
#  dense_6 (Dense)             (None, 16)                   528       ['dropout_5[0][0]']
#
#  dense_13 (Dense)            (None, 16)                   528       ['dropout_12[0][0]']
#
#  dense_17 (Dense)            (None, 64)                   8256      ['dropout_24[0][0]']
#
#  batch_normalization_6 (Bat  (None, 16)                   64        ['dense_6[0][0]']
#  chNormalization)
#
#  batch_normalization_13 (Ba  (None, 16)                   64        ['dense_13[0][0]']
#  tchNormalization)
#
#  dropout_25 (Dropout)        (None, 64)                   0         ['dense_17[0][0]']
#
#  dropout_6 (Dropout)         (None, 16)                   0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  dropout_13 (Dropout)        (None, 16)                   0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  dense_18 (Dense)            (None, 32)                   2080      ['dropout_25[0][0]']
#
#  concatenate (Concatenate)   (None, 32)                   0         ['dropout_6[0][0]',
#                                                                      'dropout_13[0][0]']
#
#  dropout_26 (Dropout)        (None, 32)                   0         ['dense_18[0][0]']
#
#  concatenate_2 (Concatenate  (None, 64)                   0         ['concatenate[0][0]',
#  )                                                                   'dropout_26[0][0]']
#
#  dense_19 (Dense)            (None, 64)                   4160      ['concatenate_2[0][0]']
#
#  dense_20 (Dense)            (None, 32)                   2080      ['dense_19[0][0]']
#
#  dense_21 (Dense)            (None, 16)                   528       ['dense_20[0][0]']
#
#  dense_22 (Dense)            (None, 8)                    136       ['dense_21[0][0]']
#
#  dense_23 (Dense)            (None, 2)                    18        ['dense_22[0][0]']
#
# ==================================================================================================
# Total params: 1792394 (6.84 MB)
# Trainable params: 1783562 (6.80 MB)
# Non-trainable params: 8832 (34.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# <a id="section6"></a>
# # <font color="#004D7F" size=6> 6. Results</font>
#
# Finally, we can evaluate our hybrid model with the images created by TINTOlib in any of the ways represented below.

# %%
score_test= modelX.evaluate([X_val_num, X_val_img], y_val_oh)
# Out:
# 125/125 [==============================] - 6s 35ms/step - loss: 0.1100 - accuracy: 0.9617 - precision: 0.9617 - recall: 0.9617 - auc: 0.9920 - f1_score: 0.9582

# %% [markdown]
# <a id="section7"></a>
# # <font color="#004D7F" size=6> 7. Aplicación de GradCAM al problema</font>

# %%
from keras.models import Model

last_conv_layer_name = "conv2d_3"
grad_model = Model(inputs=modelX.input, outputs=[modelX.output, modelX.get_layer(last_conv_layer_name).output])

# %%
import tensorflow as tf

# Assuming X_val_img is a NumPy array
X_val_img_tensor = tf.convert_to_tensor(X_val_img, dtype=tf.float32)

# %%
import numpy as np
import keras.backend as K
import cv2

single_X_val_num = X_val_num[0]  # Select the first instance from numerical data
single_X_val_img = X_val_img[0]  # Select the first image from image data
single_X_val_num = tf.expand_dims(single_X_val_num, 0)  # Add batch dimension to the numerical data
single_X_val_img = tf.expand_dims(single_X_val_img, 0)  # Add batch dimension to the image data

# Assuming you have a sample input image and its corresponding class
input_image = cv2.imread(image_paths["images"][0])  # Your input image
target_class = image_paths["class"][0]  # Target class index

# Convert the NumPy array to a TensorFlow tensor
X_val_img_tensor = tf.convert_to_tensor(X_val_img, dtype=tf.float32)

with tf.GradientTape() as tape:
    tape.watch(X_val_img_tensor)  # Ensure gradients are recorded for the image input
    conv_outputs, predictions = grad_model([X_val_num, X_val_img_tensor])
    loss = predictions[:, target_class]

output = conv_outputs[0]
grads = tape.gradient(loss, conv_outputs)[0]

# Normalizing the gradients
grads = K.l2_normalize(grads)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-41220d1b9ad2> in <cell line: 12>()
#      12 with tf.GradientTape() as tape:
#      13     tape.watch(X_val_img_tensor)  # Ensure gradients are recorded for the image input
# ---> 14     conv_outputs, predictions = grad_model([X_val_num, X_val_img_tensor])
#      15     loss = predictions[:, target_class]
#      16
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     249                 )
#     250         if spec.min_ndim is not None:
# --> 251             ndim = x.shape.rank
#     252             if ndim is not None and ndim < spec.min_ndim:
#     253                 raise ValueError(
#
# AttributeError: Exception encountered when calling layer 'model_10' (type Functional).
#
# 'tuple' object has no attribute 'rank'
#
# Call arguments received by layer 'model_10' (type Functional):
#   • inputs=['     radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \\\n180     0.957878      0.411228        0.955774   0.893531         0.512503   \n99      0.352075      0.340210        0.350287   0.211665         0.405254   \n308     0.308533      0.101454        0.289545   0.179300         0.190756   \n184     0.392778      0.429489        0.380969   0.240551         0.342512   \n282     0.587770      0.286439        0.576394   0.424814         0.461045   \n..           ...           ...             ...        ...              ...   \n352     0.887359      0.262090        0.901182   0.791729         0.562156   \n562     0.389938      0.707136        0.411927   0.243224         0.470976   \n423     0.316106      0.318566        0.315597   0.183160         0.342512   \n511     0.370533      0.168752        0.351531   0.227869         0.289699   \n14      0.319419      0.436253        0.344206   0.184433         0.545906   \n\n     compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \\\n180          0.527636        0.672680             0.933400       0.373737   \n99           0.290534        0.219963             0.290209       0.413636   \n308          0.051408        0.006462             0.021963       0.154040   \n184          0.263235        0.125937             0.162177       0.336869   \n282          0.382860        0.380975             0.470378       0.420707   \n..                ...             ...                  ...      ...
#   • training=None
#   • mask=None

# %%
heatmap = np.mean(grads, axis=-1)
heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)
heatmap = np.uint8(255 * heatmap)

# Use OpenCV to apply the heatmap to the original image
import cv2

img = cv2.imread(your_image_path)
heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
superimposed_img = heatmap * 0.4 + img

# Save or display the superimposed image
cv2.imwrite('grad_cam.jpg', superimposed_img)

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras

# Display
from IPython.display import Image, display
import matplotlib as mpl
import matplotlib.pyplot as plt

preds = modelX.predict([X_val_num, X_val_img])
i = np.argmax(preds[0])

a = np.expand_dims(X_val_num.iloc[0], axis=0)
b = np.expand_dims(X_val_img[0], axis=0)
# Out:
# 8/8 [==============================] - 0s 17ms/step

# %%
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = keras.models.Model(
        model.inputs, [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import keras.preprocessing.image

def save_and_display_gradcam(img, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Convert the image to an array
    img = keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = plt.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on the original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

    return superimposed_img

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para generar heatmap y superimposed image
def generate_heatmap_and_image(X_val_num, X_val_img, modelX, layer_name, pred_index):
    heatmap = make_gradcam_heatmap([np.expand_dims(X_val_num, axis=0), np.expand_dims(X_val_img, axis=0)], modelX, layer_name, pred_index=pred_index)
    return save_and_display_gradcam(X_val_img, heatmap)

# Función para mostrar las imágenes
def display_image(ax, row, col, image, title):
    ax[row][col].imshow(image)
    ax[row][col].set_title(title)
    ax[row][col].axis('off')

samples = 8
# Creación de la figura de subplot
fig, ax = plt.subplots(samples, 5, figsize=(20, 16))

# Datos para las imágenes
X_val_data = []
for i in range(len(y_val_oh)):
    label = "Original M" if y_val_oh[i][0] == 1 else "Original B"
    X_val_data.append((X_val_num.iloc[i], X_val_img[i], label))

# Configuración de las capas y títulos
layers = ["conv2d_3", "conv2d_7"]
titles = ["Resaltando B", "Resaltando M"]

# Procesamiento de cada caso
for i, (num, img, title) in enumerate(X_val_data[:samples]):
    display_image(ax, i, 0, img, title)

    for j, layer in enumerate(layers):
        for k, pred_index in enumerate([0, 1]):
            superimposed_img = generate_heatmap_and_image(num, img, modelX, layer, pred_index)
            display_title = f"Caso {title[-1]} {layer} {titles[pred_index]}"
            display_image(ax, i, j * 2 + k + 1, superimposed_img, display_title)

# Mostrar la figura
plt.show()

# %%
labels = label_encoder.classes_

for label, integer_value in zip(labels, range(len(labels))):
    print(f"Label: {label} -> Integer Value: {integer_value}")
# Out:
# Label: B -> Integer Value: 0
# Label: M -> Integer Value: 1

# %%
print(y_val_oh[0])
print(y_val_oh[1])
print(y_val_oh[2])
print(y_val_oh[5])
print(y_val_oh[7])
# Out:
# [1. 0.]
# [1. 0.]
# [0. 1.]
# [0. 1.]
# [0. 1.]
