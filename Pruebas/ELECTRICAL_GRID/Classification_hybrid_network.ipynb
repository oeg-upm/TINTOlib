# %% [markdown]
# <h1><font color="#113D68" size=6>TINTOlib: Converting Tidy Data into Image for 2-Dimensional Convolutional Neural Networks</font></h1>
#
# <h1><font color="#113D68" size=5>Template Classification Machine Learning problem with a Hibryd Networks (CNN+MLP)</font></h1>
#
# <br><br>
# <div style="text-align: right">
# <font color="#113D68" size=3>Manuel Castillo-Cara</font><br>
# <font color="#113D68" size=3>Raúl García-Castro</font><br>
#
# </div>
#
# ---

# %% [markdown]
# ---
#
# <a id="indice"></a>
# <h2><font color="#004D7F" size=5>Index</font></h2>
#
# * [0. Context](#section0)
# * [1. Description](#section1)
#     * [1.1. Main Features](#section11)
#     * [1.2. Citation](#section12)
#     * [1.3. Documentation and License](#section13)
# * [2. Libraries](#section2)
#     * [2.1. System setup](#section21)
#     * [2.2. Invoke the libraries](#section22)
# * [3. Data processing](#section3)
#     * [3.1. TINTOlib methods](#section31)
#     * [3.2. Read the dataset](#section32)
#     * [3.3. Generate images](#section33)
#     * [3.4. Read images](#section34)
#     * [3.5. Mix images and tidy data](#section35)
# * [4. Pre-modelling phase](#section4)
#     * [4.1. Data curation](#section41)
#     * [4.2. One-hot encoding](#section42)
# * [5. Modelling hybrid network](#section5)
#     * [5.1. FFNN for tabular data](#section51)
#     * [5.2. CNN for TINTOlib images](#section52)
#     * [5.3. Concatenate branches](#section53)
#     * [5.4. Metrics](#section54)
#     * [5.5. Compile and fit](#section55)
# * [6. Results](#section6)
#     * [6.1. Train/Validation representation](#section61)
#     * [6.2. Validation/Test evaluation](#section62)

# %% [markdown]
# ---
# <a id="section0"></a>
# # <font color="#004D7F" size=6> 0. Context</font>

# %% [markdown]
# This is a tutorial on how to read the images created by TINTOlib and pass them to a very simple pretrained Convolutional Neural Network (CNN). The images must already be created by the TINTOlib software. See the documentation in GITHUB for how to create the images from tabular data.
#
# Remember that when using CNN you can set the training to be done with GPUs to improve performance.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# You can see all information about TINTOlib code in [GitHub](https://github.com/oeg-upm/TINTOlib)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# You can see all information about TINTOlib documentation in [PyPI](https://tintolib.readthedocs.io/en/latest/installation.html)

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section1"></a>
# # <font color="#004D7F" size=6> 1. Description</font>

# %% [markdown]
# The growing interest in the use of algorithms-based machine learning for predictive tasks has generated a large and diverse development of algorithms. However, it is widely known that not all of these algorithms are adapted to efficient solutions in certain tidy data format datasets. For this reason, novel techniques are currently being developed to convert tidy data into images with the aim of using Convolutional Neural Networks (CNNs). TINTOlib offers the opportunity to convert tidy data into images through several techniques: TINTO, IGTD, REFINED, SuperTML, BarGraph, DistanceMatrix and Combination.

# %% [markdown]
# ---
# <a id="section11"></a>
# # <font color="#004D7F" size=5> 1.1. Main Features</font>

# %% [markdown]
# - Supports all CSV data in **[Tidy Data](https://www.jstatsoft.org/article/view/v059i10)** format.
# - For now, the algorithm converts tabular data for binary and multi-class classification problems into machine learning.
# - Input data formats:
#     - **Tabular files**: The input data could be in **[CSV](https://en.wikipedia.org/wiki/Comma-separated_values)**, taking into account the **[Tidy Data](https://www.jstatsoft.org/article/view/v059i10)** format.
#     - **Dataframe***: The input data could be in **[Pandas Dataframe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html)**, taking into account the **[Tidy Data](https://www.jstatsoft.org/article/view/v059i10)** format.
#     - **Tidy Data**: The **target** (variable to be predicted) should be set as the last column of the dataset. Therefore, the first columns will be the features.
#     - All data must be in numerical form. TINTOlib does not accept data in string or any other non-numeric format.
# - Runs on **Linux**, **Windows** and **macOS** systems.
# - Compatible with **[Python](https://www.python.org/)** 3.7 or higher.

# %% [markdown]
# ---
# <a id="section12"></a>
# # <font color="#004D7F" size=5> 1.2. Citation</font>

# %% [markdown]
# **TINTOlib** is an python library that makes **Synthetic Images** from [Tidy Data](https://www.jstatsoft.org/article/view/v059i10) (also knows as **Tabular Data**).
#
# **Citing TINTO**: If you used TINTO in your work, please cite the **[SoftwareX](https://doi.org/10.1016/j.softx.2023.101391)**:
#
# ```bib
# @article{softwarex_TINTO,
#     title = {TINTO: Converting Tidy Data into Image for Classification
#             with 2-Dimensional Convolutional Neural Networks},
#     journal = {SoftwareX},
#     author = {Manuel Castillo-Cara and Reewos Talla-Chumpitaz and
#               Raúl García-Castro and Luis Orozco-Barbosa},
#     year = {2023},
#     pages = {101391},
#     issn = {2352-7110},
#     doi = {https://doi.org/10.1016/j.softx.2023.101391}
# }
# ```
#
# And use-case developed in **[INFFUS Paper](https://doi.org/10.1016/j.inffus.2022.10.011)**
#
# ```bib
# @article{inffus_TINTO,
#     title = {A novel deep learning approach using blurring image
#             techniques for Bluetooth-based indoor localisation},
#     journal = {Information Fusion},
#     author = {Reewos Talla-Chumpitaz and Manuel Castillo-Cara and
#               Luis Orozco-Barbosa and Raúl García-Castro},
#     volume = {91},
#     pages = {173-186},
#     year = {2023},
#     issn = {1566-2535},
#     doi = {https://doi.org/10.1016/j.inffus.2022.10.011}
# }
# ```

# %% [markdown]
# ---
# <a id="section13"></a>
# # <font color="#004D7F" size=5> 1.3. Documentation and License</font>

# %% [markdown]
# TINTOlib has a wide range of documentation on both GitHub and PiPY.
#
# Moreover, TINTOlib is free and open software with Apache 2.0 license.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# You can see all information about TINTOlib code in [GitHub](https://github.com/oeg-upm/TINTOlib)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# You can see all information about TINTOlib documentation in [PyPI](https://tintolib.readthedocs.io/en/latest/installation.html)

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section2"></a>
# # <font color="#004D7F" size=6> 2. Libraries</font>

# %% [markdown]
# ---
# <a id="section21"></a>
# # <font color="#004D7F" size=5> 2.1. System setup</font>

# %% [markdown]
# Before installing the libraries you must have the `mpi4py` package installed on the native (Linux) system. This link shows how to install it:
# - Link: [`mpi4py` in Linux](https://www.geeksforgeeks.org/how-to-install-python3-mpi4py-package-on-linux/)
#
# For example, in Linux:
#
# ```
#     sudo apt-get install python3
#     sudo apt install python3-pip
#     sudo apt install python3-mpi4py
# ```
#
# If you are in Windows, Mac or, also, Linux, you can install from PyPI if you want:
# ```
#     sudo pip3 install mpi4py
# ```

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# Note that you must **restart the kernel or the system** so that it can load the libraries.

# %% [markdown]
# Now, once you have installed `mpi4py` you can install the PyPI libraries and dependences.

# %%
# !pip install torchmetrics pytorch_lightning TINTOlib imblearn keras_preprocessing mpi4py
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.2.1-py3-none-any.whl (806 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.1/806.1 kB 4.0 MB/s eta 0:00:00
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.1.3-py3-none-any.whl (777 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 777.7/777.7 kB 25.8 MB/s eta 0:00:00
# Collecting TINTOlib
#   Downloading tintolib-0.0.14-py3-none-any.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 31.5 MB/s eta 0:00:00
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting keras_preprocessing
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.4 MB/s eta 0:00:00
# Collecting mpi4py
#   Downloading mpi4py-3.1.5.tar.gz (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 25.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.23.5)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (23.2)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.1.0+cu121)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.10.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2023.6.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.5.0)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (from imblearn) (0.10.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras_preprocessing) (1.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.9.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (67.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (3.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->torchmetrics) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->torchmetrics) (1.3.0)
# Building wheels for collected packages: mpi4py
#   Building wheel for mpi4py (pyproject.toml) ... done
#   Created wheel for mpi4py: filename=mpi4py-3.1.5-cp310-cp310-linux_x86_64.whl size=2746500 sha256=a83f3be1aa70b04f3c15ca2a4f5eee2b43c533c97db2366555a5657053b64ed9
#   Stored in directory: /root/.cache/pip/wheels/18/2b/7f/c852523089e9182b45fca50ff56f49a51eeb6284fd25a66713
# Successfully built mpi4py
# Installing collected packages: TINTOlib, mpi4py, lightning-utilities, keras_preprocessing, torchmetrics, pytorch_lightning, imblearn
# Successfully installed TINTOlib-0.0.14 imblearn-0.0 keras_preprocessing-1.1.2 lightning-utilities-0.10.0 mpi4py-3.1.5 pytorch_lightning-2.1.3 torchmetrics-1.2.1

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# Note that you must **restart the kernel** so that it can load the libraries.

# %% [markdown]
# ---
# <a id="section22"></a>
# # <font color="#004D7F" size=5> 2.2. Invoke the libraries</font>

# %% [markdown]
# The first thing we need to do is to declare the libraries

# %%
import os
import pandas as pd
import numpy as np

np.random.seed(42)

from tqdm import tqdm
#import cv2
import gc
import matplotlib.pyplot as plt
#import openslide
#from openslide.deepzoom import DeepZoomGenerator
import tifffile as tifi
import sklearn
import tensorflow as tf
import seaborn as sns
from PIL import Image


from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score,mean_absolute_percentage_error
from sklearn.preprocessing import LabelEncoder

from keras_preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model

from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import vgg16, vgg19, resnet50, mobilenet, inception_resnet_v2, densenet, inception_v3, xception, nasnet, ResNet152V2
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, InputLayer, LayerNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import SGD, Adam, Adadelta, Adamax
from tensorflow.keras import layers, models, Model
from tensorflow.keras.losses import MeanAbsoluteError, MeanAbsolutePercentageError
from tensorflow.keras.layers import Input, Activation,MaxPooling2D, concatenate
from tensorflow.keras.utils import to_categorical

from imblearn.over_sampling import RandomOverSampler

#Models of TINTOlib
from TINTOlib.tinto import TINTO
from TINTOlib.supertml import SuperTML
from TINTOlib.igtd import IGTD
from TINTOlib.refined import REFINED
from TINTOlib.barGraph import BarGraph
from TINTOlib.distanceMatrix import DistanceMatrix
from TINTOlib.combination import Combination
import TINTOlib.utils

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section3"></a>
# # <font color="#004D7F" size=6> 3. Data processing</font>

# %% [markdown]
# The first thing to do is to read all the images created by TINTO. TINTO creates a folder which contains subfolders corresponding to each target that has the problem. Each image corresponds to a sample of the original dataset.

# %% [markdown]
# ---
# <a id="section31"></a>
# # <font color="#004D7F" size=5> 3.1. TINTOlib methods</font>

# %% [markdown]
# We prepare the declaration of the classes with the TINTOlib method we want to transform. Note that TINTOlib has several methods and we will have to choose one of them since each method generates different images.
#
# In addition, we establish the paths where the dataset is located and also the folder where the images will be created.

# %%
pixels = 20

# %%
#Select the model and the parameters
problem_type = "supervised"
#image_model = REFINED(problem= problem_type,hcIterations=5)
image_model = TINTO(problem= problem_type,blur=False,pixels=pixels)
#image_model = IGTD(problem= problem_type)
#image_model = BarGraph(problem= problem_type)
#image_model = DistanceMatrix(problem= problem_type)
#image_model = Combination(problem= problem_type)

#Define the dataset path and the folder where the images will be saved
dataset_path = "/content/drive/MyDrive/Máster UNED/TFM/Datasets/Data_for_UCI_named.csv"
images_folder = "hybridclassification"

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# You can see all TINTOlib method in the [PyPI documentation](https://tintolib.readthedocs.io/en/latest/installation.html)

# %% [markdown]
# ---
# <a id="section32"></a>
# # <font color="#004D7F" size=5> 3.2. Read the dataset</font>

# %% [markdown]
# In this part, we proceed to read the dataset according to the path specified above and also standardize the name that the target will have, in this case, it will be called `class`.

# %%
#Read CSV
df=pd.read_csv(dataset_path, delimiter=';')

df.pop('stab')

column_to_move = df.pop('stabf')
df['stabf'] = column_to_move

class_col = df.iloc[:,-1]
df = df.iloc[: , :-1]
df['stabf'] = class_col
df
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4     stabf
# 0    -1.723086  0.650456  0.859578  0.887445  0.958034  unstable
# 1    -1.255012  0.413441  0.862414  0.562139  0.781760    stable
# 2    -0.920492  0.163041  0.766689  0.839444  0.109853  unstable
# 3    -0.997374  0.446209  0.976744  0.929381  0.362718  unstable
# 4    -0.554305  0.797110  0.455450  0.656947  0.820923  unstable
# ...        ...       ...       ...       ...       ...       ...
# 9995 -1.236256  0.601709  0.779642  0.813512  0.608385  unstable
# 9996 -1.733414  0.502079  0.567242  0.285880  0.366120    stable
# 9997 -1.975373  0.487838  0.986505  0.149286  0.145984    stable
# 9998 -0.898510  0.365246  0.587558  0.889118  0.818391  unstable
# 9999 -0.570329  0.073056  0.505441  0.378761  0.942631  unstable
#
# [10000 rows x 13 columns]

# %% [markdown]
# ---
# <a id="section33"></a>
# # <font color="#004D7F" size=5> 3.3. Generate images</font>

# %% [markdown]
# Now we can generate the images with the `generateImages()` generic function. Likewise, we create a dataset that will have the path of each of the samples with the corresponding image created for it.
#
# Note that each image is created based on a row, therefore, each numerical sample of the dataset will correspond to a particular image. In other words, we will have the same number of images as samples/rows.

# %%
image_model.generateImages(df, images_folder)
img_paths = os.path.join(images_folder,problem_type+".csv")

print(img_paths)
# Out:
# hybridclassification/supervised.csv

# %%
img_paths = os.path.join(images_folder,problem_type+".csv")

# %% [markdown]
# ---
# <a id="section34"></a>
# # <font color="#004D7F" size=5> 3.4. Read Images</font>

# %% [markdown]
# Now, we read the created images

# %%
imgs = pd.read_csv(img_paths)

#imgs["images"]= images_folder + "\\" + imgs["images"]
imgs["images"]= images_folder + "/" + imgs["images"]

# %% [markdown]
# ---
# <a id="section35"></a>
# # <font color="#004D7F" size=5> 3.5. Mix images and tidy data</font>

# %% [markdown]
# Since we are going to use hybrid networks, i.e. create a model in which we join a CNN for the images and a MLP for the tabular data, we are going to join it in order to integrate all the data in our hybrid model.

# %%
# Select all the attributes to normalize
columns_to_normalize = df.columns[:-1]

# Normalize between 0 and 1
df_normalized = (df[columns_to_normalize] - df[columns_to_normalize].min()) / (df[columns_to_normalize].max() - df[columns_to_normalize].min())

# Combine the attributes and the label
df_normalized = pd.concat([df_normalized, df[df.columns[-1]]], axis=1)

df_normalized.head(2)
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  0.258801  0.271561  0.829616  0.976978  0.509244  0.811642  0.495075
# 1  0.926793  0.463424  0.268117  0.091471  0.813957  0.039894  0.084809
#
#          p4        g1        g2        g3        g4     stabf
# 0  0.184572  0.632098  0.852229  0.881531  0.955894  unstable
# 1  0.496642  0.382588  0.855215  0.539078  0.770323    stable

# %% [markdown]
# Combine the images and tidy data in the same dataframe, split attributes and objective value

# %%
combined_dataset = pd.concat([imgs,df_normalized],axis=1)

df_x = combined_dataset.drop("stabf",axis=1)
df_x.pop('class')
df_y = combined_dataset["stabf"]

print(df_y)
# Out:
# 0       unstable
# 1         stable
# 2       unstable
# 3       unstable
# 4       unstable
#           ...
# 9995    unstable
# 9996      stable
# 9997      stable
# 9998    unstable
# 9999    unstable
# Name: stabf, Length: 10000, dtype: object

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section4"></a>
# # <font color="#004D7F" size=6> 4. Pre-modelling phase</font>

# %% [markdown]
# Once the data is ready, we load it into memory with an iterator in order to pass it to the CNN.

# %% [markdown]
# ---
# <a id="section41"></a>
# # <font color="#004D7F" size=5> 4.1. Data curation</font>

# %% [markdown]
# Note that each method generates images of **different pixel size**. For example:
# - `TINTO` method has a parameter that you can specify the size in pixels which by default is 20.
# - Other parameters such as `Combined` generates the size automatically and you must obtain them from the _shape_ of the images.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# You can see all information about TINTOlib documentation in [PyPI](https://tintolib.readthedocs.io/en/latest/installation.html)

# %%
label_encoder = LabelEncoder()
df_y = label_encoder.fit_transform(df_y)

# %%
labels = label_encoder.classes_

for label, integer_value in zip(labels, range(len(labels))):
    print(f"Label: {label} -> Integer Value: {integer_value}")
# Out:
# Label: stable -> Integer Value: 0
# Label: unstable -> Integer Value: 1

# %% [markdown]
# Split in train/test/validation.
#
# Note that the partitioning of the images is also performed, in addition to the tabular data.

# %%
import cv2
X_train, X_val, y_train, y_val = train_test_split(df_x, df_y, test_size = 0.30, random_state = 42,stratify=df_y)
#X_val, X_test, y_val, y_test = train_test_split(X_val, y_val, test_size = 0.50, random_state = 123,stratify=y_val)

X_train_num = X_train.drop("images",axis=1)
X_val_num = X_val.drop("images",axis=1)
#X_test_num = X_test.drop("images",axis=1)

"""X_train_img = np.array([cv2.imread(img) for img in X_train["images"]])
X_val_img = np.array([cv2.imread(img) for img in X_val["images"]])
X_test_img = np.array([cv2.imread(img) for img in X_test["images"]])"""

X_train_img = np.array([cv2.resize(cv2.imread(img),(pixels,pixels)) for img in X_train["images"]])
X_val_img = np.array([cv2.resize(cv2.imread(img),(pixels,pixels)) for img in X_val["images"]])
#X_test_img = np.array([cv2.resize(cv2.imread(img),(pixels,pixels)) for img in X_test["images"]])

n_class = df['stabf'].value_counts().count()
attributes = len(X_train_num.columns)

print("Image shape",X_train_img[0].shape)
print("Attributes",attributes)
print("Classes",n_class)
size=X_train_img[0].shape[0]
print("Image size (pixels):", pixels)
# Out:
# Image shape (20, 20, 3)
# Attributes 12
# Classes 2
# Image size (pixels): 20

# %%
df
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4     stabf
# 0    -1.723086  0.650456  0.859578  0.887445  0.958034  unstable
# 1    -1.255012  0.413441  0.862414  0.562139  0.781760    stable
# 2    -0.920492  0.163041  0.766689  0.839444  0.109853  unstable
# 3    -0.997374  0.446209  0.976744  0.929381  0.362718  unstable
# 4    -0.554305  0.797110  0.455450  0.656947  0.820923  unstable
# ...        ...       ...       ...       ...       ...       ...
# 9995 -1.236256  0.601709  0.779642  0.813512  0.608385  unstable
# 9996 -1.733414  0.502079  0.567242  0.285880  0.366120    stable
# 9997 -1.975373  0.487838  0.986505  0.149286  0.145984    stable
# 9998 -0.898510  0.365246  0.587558  0.889118  0.818391  unstable
# 9999 -0.570329  0.073056  0.505441  0.378761  0.942631  unstable
#
# [10000 rows x 13 columns]

# %% [markdown]
# ---
# <a id="section42"></a>
# # <font color="#004D7F" size=5> 4.2. One-hot encoding</font>

# %% [markdown]
# One-hot encoding **only** for multiclass machine learning problems

# %%
# y-1 because target is between [1,28] and not [0,27]
y_train_oh =  to_categorical(y_train-1,n_class)
y_val_oh = to_categorical(y_val-1,n_class)
#y_test_oh = to_categorical(y_test-1,n_class)

# %%
df_x.dtypes
# Out:
# images     object
# tau1      float64
# tau2      float64
# tau3      float64
# tau4      float64
# p1        float64
# p2        float64
# p3        float64
# p4        float64
# g1        float64
# g2        float64
# g3        float64
# g4        float64
# dtype: object

# %% [markdown]
# <a id="section5"></a>
# # <font color="#004D7F" size=6> 5. Modeling hybrid network</font>

# %% [markdown]
# Now we can start the CNN+MLP training. Before that we prepare the algorithm for reading data.
#
# In this example, 2 branch networks is created
# - 1º branch: FFNN for tabular data
# - 2º branch: CNN for TINTOlib images

# %% [markdown]
# ---
# <a id="section51"></a>
# # <font color="#004D7F" size=5> 5.1. FFNN for tabular data</font>
#
# This is an example of a simple FFNN for tabular data. Note that we are not looking for the optimization of the CNN but to show an example of TINTOlib execution.

# %%
dropout = 0.5

# %%
filters_ffnn = [128,64,32]

ff_model = Sequential()
ff_model.add(Input(shape=(attributes,)))

for layer in filters_ffnn:
    ff_model.add(Dense(layer, activation="relu"))
    ff_model.add(BatchNormalization())
    ff_model.add(Dropout(dropout))

# %% [markdown]
# ---
# <a id="section52"></a>
# # <font color="#004D7F" size=5> 5.2. CNN for TINTOlib images</font>
#
# This is an example of a simple CNN for TINTOlib images. Note that we are not looking for the optimization of the CNN but to show an example of TINTOlib execution.

# %%
filters_cnn =  [16,32,64,128]

cnn_model = Sequential()
cnn_model.add(Input(shape=(pixels,pixels, 3)))

for layer in filters_cnn:
    cnn_model.add(Conv2D(layer, (3, 3), padding="same"))
    cnn_model.add(Activation("relu"))
    cnn_model.add(BatchNormalization())
    cnn_model.add(MaxPooling2D(pool_size=(2, 2)))

# flatten the volume, then FC => RELU => BN => DROPOUT
cnn_model.add(Flatten())
cnn_model.add(Dense(128))
cnn_model.add(Activation("relu"))
cnn_model.add(BatchNormalization())
cnn_model.add(Dropout(dropout))
cnn_model.add(Dense(64))
cnn_model.add(Activation("relu"))
cnn_model.add(BatchNormalization())
cnn_model.add(Dropout(dropout))
# apply another FC layer, this one to match the number of nodes
# coming out of the MLP
cnn_model.add(Dense(32))
cnn_model.add(Activation("relu"))
cnn_model.add(BatchNormalization())
cnn_model.add(Dropout(dropout))

# %% [markdown]
# ---
# <a id="section53"></a>
# # <font color="#004D7F" size=5> 5.3. Concatenate branches</font>
#
# Finally, we must concatenate the output of the CNN branch with the output of the FFNN branch in a final FFNN that will give the predictions.

# %%
combinedInput = concatenate([ff_model.output, cnn_model.output])
x = Dense(64, activation="relu")(combinedInput)
x = BatchNormalization()(x)
x = Dropout(dropout)(x)
x = Dense(64, activation="relu")(x)
x = BatchNormalization()(x)
x = Dropout(dropout)(x)
x = Dense(64, activation="relu")(x)
x = BatchNormalization()(x)
x = Dropout(dropout)(x)
x = Dense(n_class, activation="softmax")(x)

model = Model(inputs=[ff_model.input, cnn_model.input], outputs=x)

# %% [markdown]
# ---
# <a id="section54"></a>
# # <font color="#004D7F" size=5> 5.4. Metrics</font>
#
# Define metrics and some hyperparameters

# %%
METRICS = [
    #tf.keras.metrics.TruePositives(name = 'tp'),
    #tf.keras.metrics.FalsePositives(name = 'fp'),
    #tf.keras.metrics.TrueNegatives(name = 'tn'),
    #tf.keras.metrics.FalseNegatives(name = 'fn'),
    tf.keras.metrics.BinaryAccuracy(name ='accuracy'),
    tf.keras.metrics.Precision(name = 'precision'),
    tf.keras.metrics.Recall(name = 'recall'),
    tf.keras.metrics.AUC(name = 'auc'),
    tf.keras.metrics.F1Score(name='f1_score')
]

# %% [markdown]
# Print the model

# %%
from keras.utils import plot_model
model.summary()
plot_model(model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 20, 20, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 20, 20, 16)           448       ['input_2[0][0]']
#
#  activation (Activation)     (None, 20, 20, 16)           0         ['conv2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 20, 20, 16)           64        ['activation[0][0]']
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 10, 10, 16)           0         ['batch_normalization_3[0][0]'
#  D)                                                                 ]
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 32)           4640      ['max_pooling2d[0][0]']
#
#  activation_1 (Activation)   (None, 10, 10, 32)           0         ['conv2d_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 10, 10, 32)           128       ['activation_1[0][0]']
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 32)             0         ['batch_normalization_4[0][0]'
#  g2D)                                                               ]
#
#  conv2d_2 (Conv2D)           (None, 5, 5, 64)             18496     ['max_pooling2d_1[0][0]']
#
#  activation_2 (Activation)   (None, 5, 5, 64)             0         ['conv2d_2[0][0]']
#
#  batch_normalization_5 (Bat  (None, 5, 5, 64)             256       ['activation_2[0][0]']
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 64)             0         ['batch_normalization_5[0][0]'
#  g2D)                                                               ]
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 128)            73856     ['max_pooling2d_2[0][0]']
#
#  activation_3 (Activation)   (None, 2, 2, 128)            0         ['conv2d_3[0][0]']
#
#  batch_normalization_6 (Bat  (None, 2, 2, 128)            512       ['activation_3[0][0]']
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 1, 1, 128)            0         ['batch_normalization_6[0][0]'
#  g2D)                                                               ]
#
#  flatten (Flatten)           (None, 128)                  0         ['max_pooling2d_3[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  16512     ['flatten[0][0]']
#
#  activation_4 (Activation)   (None, 128)                  0         ['dense_3[0][0]']
#
#  input_1 (InputLayer)        [(None, 12)]                 0         []
#
#  batch_normalization_7 (Bat  (None, 128)                  512       ['activation_4[0][0]']
#  chNormalization)
#
#  dense (Dense)               (None, 128)                  1664      ['input_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  batch_normalization (Batch  (None, 128)                  512       ['dense[0][0]']
#  Normalization)
#
#  dense_4 (Dense)             (None, 64)                   8256      ['dropout_3[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['batch_normalization[0][0]']
#
#  activation_5 (Activation)   (None, 64)                   0         ['dense_4[0][0]']
#
#  dense_1 (Dense)             (None, 64)                   8256      ['dropout[0][0]']
#
#  batch_normalization_8 (Bat  (None, 64)                   256       ['activation_5[0][0]']
#  chNormalization)
#
#  batch_normalization_1 (Bat  (None, 64)                   256       ['dense_1[0][0]']
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 64)                   0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 64)                   0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dense_5 (Dense)             (None, 32)                   2080      ['dropout_4[0][0]']
#
#  dense_2 (Dense)             (None, 32)                   2080      ['dropout_1[0][0]']
#
#  activation_6 (Activation)   (None, 32)                   0         ['dense_5[0][0]']
#
#  batch_normalization_2 (Bat  (None, 32)                   128       ['dense_2[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 32)                   128       ['activation_6[0][0]']
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 32)                   0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_5 (Dropout)         (None, 32)                   0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  concatenate (Concatenate)   (None, 64)                   0         ['dropout_2[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_6 (Dense)             (None, 64)                   4160      ['concatenate[0][0]']
#
#  batch_normalization_10 (Ba  (None, 64)                   256       ['dense_6[0][0]']
#  tchNormalization)
#
#  dropout_6 (Dropout)         (None, 64)                   0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  dense_7 (Dense)             (None, 64)                   4160      ['dropout_6[0][0]']
#
#  batch_normalization_11 (Ba  (None, 64)                   256       ['dense_7[0][0]']
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                   0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  dense_8 (Dense)             (None, 64)                   4160      ['dropout_7[0][0]']
#
#  batch_normalization_12 (Ba  (None, 64)                   256       ['dense_8[0][0]']
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 64)                   0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  dense_9 (Dense)             (None, 2)                    130       ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 152418 (595.38 KB)
# Trainable params: 150658 (588.51 KB)
# Non-trainable params: 1760 (6.88 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ---
# <a id="section55"></a>
# # <font color="#004D7F" size=5> 5.5. Compile and fit</font>
#
# Note to specify the **loss depending** on whether you have a binary or multiclass classification problem.

# %%
def create_model():
  filters_cnn =  [16,32,64,128]

  cnn_model = Sequential()
  cnn_model.add(Input(shape=(pixels,pixels, 3)))

  for layer in filters_cnn:
      cnn_model.add(Conv2D(layer, (3, 3), padding="same"))
      cnn_model.add(Activation("relu"))
      cnn_model.add(BatchNormalization())
      cnn_model.add(MaxPooling2D(pool_size=(2, 2)))

  # flatten the volume, then FC => RELU => BN => DROPOUT
  cnn_model.add(Flatten())
  cnn_model.add(Dense(128))
  cnn_model.add(Activation("relu"))
  cnn_model.add(BatchNormalization())
  cnn_model.add(Dropout(dropout))
  cnn_model.add(Dense(64))
  cnn_model.add(Activation("relu"))
  cnn_model.add(BatchNormalization())
  cnn_model.add(Dropout(dropout))
  # apply another FC layer, this one to match the number of nodes
  # coming out of the MLP
  cnn_model.add(Dense(32))
  cnn_model.add(Activation("relu"))
  cnn_model.add(BatchNormalization())
  cnn_model.add(Dropout(dropout))

  combinedInput = concatenate([ff_model.output, cnn_model.output])
  x = Dense(64, activation="relu")(combinedInput)
  x = BatchNormalization()(x)
  x = Dropout(dropout)(x)
  x = Dense(64, activation="relu")(x)
  x = BatchNormalization()(x)
  x = Dropout(dropout)(x)
  x = Dense(64, activation="relu")(x)
  x = BatchNormalization()(x)
  x = Dropout(dropout)(x)
  x = Dense(2, activation="softmax")(x)

  return Model(inputs=[ff_model.input, cnn_model.input], outputs=x)

# %%
#HYPERPARAMETERS
opt = Adam(learning_rate=1e-3)
#opt = tf.keras.optimizers.RMSprop(learning_rate=0.001)

# %%
model=create_model()

model.compile(
    loss="binary_crossentropy",
    optimizer=opt,
    metrics = METRICS
)
epochs = 500

# %%
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from keras.callbacks import LearningRateScheduler
lr_sched = LearningRateScheduler(lambda epoch: 1e-3 * (0.75 ** np.floor(epoch / 2))) #No mejora
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)

# %%
model_history=model.fit(
    x=[X_train_num, X_train_img], y=y_train_oh,
    validation_data=([X_val_num, X_val_img], y_val_oh),
    epochs=epochs ,
    batch_size=16,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/500
# 438/438 [==============================] - 20s 29ms/step - loss: 0.6501 - accuracy: 0.7791 - precision: 0.7791 - recall: 0.7791 - auc: 0.8710 - f1_score: 0.7588 - val_loss: 0.3281 - val_accuracy: 0.8577 - val_precision: 0.8577 - val_recall: 0.8577 - val_auc: 0.9440 - val_f1_score: 0.8388
# Epoch 2/500
# 438/438 [==============================] - 10s 24ms/step - loss: 0.4705 - accuracy: 0.7994 - precision: 0.7994 - recall: 0.7994 - auc: 0.8707 - f1_score: 0.7766 - val_loss: 0.2985 - val_accuracy: 0.8743 - val_precision: 0.8743 - val_recall: 0.8743 - val_auc: 0.9560 - val_f1_score: 0.8586
# Epoch 3/500
# 438/438 [==============================] - 11s 24ms/step - loss: 0.4280 - accuracy: 0.8150 - precision: 0.8150 - recall: 0.8150 - auc: 0.8893 - f1_score: 0.7944 - val_loss: 0.2999 - val_accuracy: 0.8740 - val_precision: 0.8740 - val_recall: 0.8740 - val_auc: 0.9496 - val_f1_score: 0.8538
# Epoch 4/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.3921 - accuracy: 0.8281 - precision: 0.8281 - recall: 0.8281 - auc: 0.9051 - f1_score: 0.8091 - val_loss: 0.2936 - val_accuracy: 0.8753 - val_precision: 0.8753 - val_recall: 0.8753 - val_auc: 0.9557 - val_f1_score: 0.8552
# Epoch 5/500
# 438/438 [==============================] - 11s 26ms/step - loss: 0.3974 - accuracy: 0.8317 - precision: 0.8317 - recall: 0.8317 - auc: 0.9033 - f1_score: 0.8139 - val_loss: 0.2620 - val_accuracy: 0.9063 - val_precision: 0.9063 - val_recall: 0.9063 - val_auc: 0.9699 - val_f1_score: 0.8944
# Epoch 6/500
# 438/438 [==============================] - 10s 22ms/step - loss: 0.3730 - accuracy: 0.8379 - precision: 0.8379 - recall: 0.8379 - auc: 0.9132 - f1_score: 0.8217 - val_loss: 0.2483 - val_accuracy: 0.9123 - val_precision: 0.9123 - val_recall: 0.9123 - val_auc: 0.9728 - val_f1_score: 0.9022
# Epoch 7/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.3621 - accuracy: 0.8407 - precision: 0.8407 - recall: 0.8407 - auc: 0.9184 - f1_score: 0.8252 - val_loss: 0.2584 - val_accuracy: 0.9107 - val_precision: 0.9107 - val_recall: 0.9107 - val_auc: 0.9741 - val_f1_score: 0.9003
# Epoch 8/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.3573 - accuracy: 0.8454 - precision: 0.8454 - recall: 0.8454 - auc: 0.9197 - f1_score: 0.8305 - val_loss: 0.2451 - val_accuracy: 0.9323 - val_precision: 0.9323 - val_recall: 0.9323 - val_auc: 0.9841 - val_f1_score: 0.9263
# Epoch 9/500
# 438/438 [==============================] - 9s 21ms/step - loss: 0.3327 - accuracy: 0.8546 - precision: 0.8546 - recall: 0.8546 - auc: 0.9307 - f1_score: 0.8409 - val_loss: 0.3623 - val_accuracy: 0.8330 - val_precision: 0.8330 - val_recall: 0.8330 - val_auc: 0.9181 - val_f1_score: 0.8305
# Epoch 10/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.3502 - accuracy: 0.8444 - precision: 0.8444 - recall: 0.8444 - auc: 0.9232 - f1_score: 0.8300 - val_loss: 0.2728 - val_accuracy: 0.8940 - val_precision: 0.8940 - val_recall: 0.8940 - val_auc: 0.9677 - val_f1_score: 0.8899
# Epoch 11/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.3198 - accuracy: 0.8584 - precision: 0.8584 - recall: 0.8584 - auc: 0.9357 - f1_score: 0.8455 - val_loss: 0.3043 - val_accuracy: 0.8697 - val_precision: 0.8697 - val_recall: 0.8697 - val_auc: 0.9470 - val_f1_score: 0.8662
# Epoch 12/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.3192 - accuracy: 0.8551 - precision: 0.8551 - recall: 0.8551 - auc: 0.9351 - f1_score: 0.8429 - val_loss: 0.2207 - val_accuracy: 0.9350 - val_precision: 0.9350 - val_recall: 0.9350 - val_auc: 0.9854 - val_f1_score: 0.9283
# Epoch 13/500
# 438/438 [==============================] - 10s 24ms/step - loss: 0.3113 - accuracy: 0.8663 - precision: 0.8663 - recall: 0.8663 - auc: 0.9388 - f1_score: 0.8542 - val_loss: 0.3166 - val_accuracy: 0.8700 - val_precision: 0.8700 - val_recall: 0.8700 - val_auc: 0.9445 - val_f1_score: 0.8664
# Epoch 14/500
# 438/438 [==============================] - 12s 26ms/step - loss: 0.2904 - accuracy: 0.8727 - precision: 0.8727 - recall: 0.8727 - auc: 0.9457 - f1_score: 0.8618 - val_loss: 0.2367 - val_accuracy: 0.9017 - val_precision: 0.9017 - val_recall: 0.9017 - val_auc: 0.9686 - val_f1_score: 0.8871
# Epoch 15/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.2982 - accuracy: 0.8710 - precision: 0.8710 - recall: 0.8710 - auc: 0.9427 - f1_score: 0.8603 - val_loss: 0.3517 - val_accuracy: 0.8220 - val_precision: 0.8220 - val_recall: 0.8220 - val_auc: 0.9206 - val_f1_score: 0.8202
# Epoch 16/500
# 438/438 [==============================] - 10s 23ms/step - loss: 0.2964 - accuracy: 0.8713 - precision: 0.8713 - recall: 0.8713 - auc: 0.9440 - f1_score: 0.8601 - val_loss: 0.2554 - val_accuracy: 0.8793 - val_precision: 0.8793 - val_recall: 0.8793 - val_auc: 0.9624 - val_f1_score: 0.8759
# Epoch 17/500
# 438/438 [==============================] - 11s 26ms/step - loss: 0.2863 - accuracy: 0.8821 - precision: 0.8821 - recall: 0.8821 - auc: 0.9472 - f1_score: 0.8721 - val_loss: 0.2122 - val_accuracy: 0.9203 - val_precision: 0.9203 - val_recall: 0.9203 - val_auc: 0.9813 - val_f1_score: 0.9159
# Epoch 18/500
# 438/438 [==============================] - 11s 26ms/step - loss: 0.2776 - accuracy: 0.8823 - precision: 0.8823 - recall: 0.8823 - auc: 0.9501 - f1_score: 0.8718 - val_loss: 0.2022 - val_accuracy: 0.9160 - val_precision: 0.9160 - val_recall: 0.9160 - val_auc: 0.9758 - val_f1_score: 0.9042
# Epoch 19/500
# 438/438 [==============================] - 10s 22ms/step - loss: 0.2755 - accuracy: 0.8803 - precision: 0.8803 - recall: 0.8803 - auc: 0.9504 - f1_score: 0.8700 - val_loss: 0.2148 - val_accuracy: 0.9277 - val_precision: 0.9277 - val_recall: 0.9277 - val_auc: 0.9834 - val_f1_score: 0.9241
# Epoch 20/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.2712 - accuracy: 0.8844 - precision: 0.8844 - recall: 0.8844 - auc: 0.9531 - f1_score: 0.8745 - val_loss: 0.3584 - val_accuracy: 0.7933 - val_precision: 0.7933 - val_recall: 0.7933 - val_auc: 0.9154 - val_f1_score: 0.7923
# Epoch 21/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.2605 - accuracy: 0.8893 - precision: 0.8893 - recall: 0.8893 - auc: 0.9562 - f1_score: 0.8801 - val_loss: 0.2354 - val_accuracy: 0.8900 - val_precision: 0.8900 - val_recall: 0.8900 - val_auc: 0.9650 - val_f1_score: 0.8716
# Epoch 22/500
# 438/438 [==============================] - 9s 21ms/step - loss: 0.2548 - accuracy: 0.8900 - precision: 0.8900 - recall: 0.8900 - auc: 0.9572 - f1_score: 0.8805 - val_loss: 0.4979 - val_accuracy: 0.7370 - val_precision: 0.7370 - val_recall: 0.7370 - val_auc: 0.8544 - val_f1_score: 0.7370
# Epoch 23/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.2497 - accuracy: 0.8941 - precision: 0.8941 - recall: 0.8941 - auc: 0.9586 - f1_score: 0.8852 - val_loss: 0.4735 - val_accuracy: 0.7253 - val_precision: 0.7253 - val_recall: 0.7253 - val_auc: 0.8490 - val_f1_score: 0.7253
# Epoch 24/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.2524 - accuracy: 0.8926 - precision: 0.8926 - recall: 0.8926 - auc: 0.9584 - f1_score: 0.8831 - val_loss: 0.1874 - val_accuracy: 0.9163 - val_precision: 0.9163 - val_recall: 0.9163 - val_auc: 0.9810 - val_f1_score: 0.9126
# Epoch 25/500
# 438/438 [==============================] - 9s 22ms/step - loss: 0.2563 - accuracy: 0.8916 - precision: 0.8916 - recall: 0.8916 - auc: 0.9570 - f1_score: 0.8828 - val_loss: 0.1710 - val_accuracy: 0.9280 - val_precision: 0.9280 - val_recall: 0.9280 - val_auc: 0.9835 - val_f1_score: 0.9188
# Epoch 26/500
# 438/438 [==============================] - 11s 26ms/step - loss: 0.2552 - accuracy: 0.8893 - precision: 0.8893 - recall: 0.8893 - auc: 0.9574 - f1_score: 0.8802 - val_loss: 0.2115 - val_accuracy: 0.9037 - val_precision: 0.9037 - val_recall: 0.9037 - val_auc: 0.9756 - val_f1_score: 0.9004
# Epoch 27/500
# 438/438 [==============================] - 11s 26ms/step - loss: 0.2559 - accuracy: 0.8869 - precision: 0.8869 - recall: 0.8869 - auc: 0.9567 - f1_score: 0.8770 - val_loss: 0.3195 - val_accuracy: 0.8277 - val_precision: 0.8277 - val_recall: 0.8277 - val_auc: 0.9328 - val_f1_score: 0.7845
# Epoch 28/500
# 438/438 [==============================] - 9s 21ms/step - loss: 0.2532 - accuracy: 0.8951 - precision: 0.8951 - recall: 0.8951 - auc: 0.9579 - f1_score: 0.8859 - val_loss: 0.4556 - val_accuracy: 0.7763 - val_precision: 0.7763 - val_recall: 0.7763 - val_auc: 0.8816 - val_f1_score: 0.7757
# Epoch 29/500
# 438/438 [==============================] - 12s 26ms/step - loss: 0.2405 - accuracy: 0.9004 - precision: 0.9004 - recall: 0.9004 - auc: 0.9620 - f1_score: 0.8917 - val_loss: 0.2568 - val_accuracy: 0.8667 - val_precision: 0.8667 - val_recall: 0.8667 - val_auc: 0.9559 - val_f1_score: 0.8402
# Epoch 30/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.2285 - accuracy: 0.9019 - precision: 0.9019 - recall: 0.9019 - auc: 0.9646 - f1_score: 0.8938 - val_loss: 0.1400 - val_accuracy: 0.9433 - val_precision: 0.9433 - val_recall: 0.9433 - val_auc: 0.9901 - val_f1_score: 0.9378
# Epoch 31/500
# 438/438 [==============================] - 9s 21ms/step - loss: 0.2427 - accuracy: 0.8970 - precision: 0.8970 - recall: 0.8970 - auc: 0.9609 - f1_score: 0.8883 - val_loss: 0.3348 - val_accuracy: 0.8127 - val_precision: 0.8127 - val_recall: 0.8127 - val_auc: 0.9329 - val_f1_score: 0.8112
# Epoch 32/500
# 438/438 [==============================] - 12s 26ms/step - loss: 0.2389 - accuracy: 0.8994 - precision: 0.8994 - recall: 0.8994 - auc: 0.9616 - f1_score: 0.8911 - val_loss: 0.2207 - val_accuracy: 0.8813 - val_precision: 0.8813 - val_recall: 0.8813 - val_auc: 0.9686 - val_f1_score: 0.8605
# Epoch 33/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.2411 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9612 - f1_score: 0.8973 - val_loss: 0.7582 - val_accuracy: 0.6653 - val_precision: 0.6653 - val_recall: 0.6653 - val_auc: 0.7850 - val_f1_score: 0.6642
# Epoch 34/500
# 438/438 [==============================] - 9s 21ms/step - loss: 0.2240 - accuracy: 0.9121 - precision: 0.9121 - recall: 0.9121 - auc: 0.9662 - f1_score: 0.9047 - val_loss: 0.1749 - val_accuracy: 0.9183 - val_precision: 0.9183 - val_recall: 0.9183 - val_auc: 0.9843 - val_f1_score: 0.9072
# Epoch 35/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.2228 - accuracy: 0.9096 - precision: 0.9096 - recall: 0.9096 - auc: 0.9661 - f1_score: 0.9019 - val_loss: 0.1322 - val_accuracy: 0.9440 - val_precision: 0.9440 - val_recall: 0.9440 - val_auc: 0.9915 - val_f1_score: 0.9380
# Epoch 36/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.2207 - accuracy: 0.9089 - precision: 0.9089 - recall: 0.9089 - auc: 0.9664 - f1_score: 0.9010 - val_loss: 0.1489 - val_accuracy: 0.9417 - val_precision: 0.9417 - val_recall: 0.9417 - val_auc: 0.9885 - val_f1_score: 0.9381
# Epoch 37/500
# 438/438 [==============================] - 9s 21ms/step - loss: 0.2302 - accuracy: 0.9061 - precision: 0.9061 - recall: 0.9061 - auc: 0.9649 - f1_score: 0.8987 - val_loss: 0.1844 - val_accuracy: 0.9140 - val_precision: 0.9140 - val_recall: 0.9140 - val_auc: 0.9794 - val_f1_score: 0.9019
# Epoch 38/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.2225 - accuracy: 0.9107 - precision: 0.9107 - recall: 0.9107 - auc: 0.9667 - f1_score: 0.9032 - val_loss: 0.2252 - val_accuracy: 0.8877 - val_precision: 0.8877 - val_recall: 0.8877 - val_auc: 0.9694 - val_f1_score: 0.8842
# Epoch 39/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.2189 - accuracy: 0.9100 - precision: 0.9100 - recall: 0.9100 - auc: 0.9672 - f1_score: 0.9025 - val_loss: 0.5009 - val_accuracy: 0.7487 - val_precision: 0.7487 - val_recall: 0.7487 - val_auc: 0.8798 - val_f1_score: 0.7485
# Epoch 40/500
# 438/438 [==============================] - 9s 21ms/step - loss: 0.2126 - accuracy: 0.9143 - precision: 0.9143 - recall: 0.9143 - auc: 0.9694 - f1_score: 0.9071 - val_loss: 0.2958 - val_accuracy: 0.8440 - val_precision: 0.8440 - val_recall: 0.8440 - val_auc: 0.9491 - val_f1_score: 0.8416
# Epoch 41/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1990 - accuracy: 0.9201 - precision: 0.9201 - recall: 0.9201 - auc: 0.9714 - f1_score: 0.9138 - val_loss: 0.1326 - val_accuracy: 0.9447 - val_precision: 0.9447 - val_recall: 0.9447 - val_auc: 0.9912 - val_f1_score: 0.9409
# Epoch 42/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.2142 - accuracy: 0.9204 - precision: 0.9204 - recall: 0.9204 - auc: 0.9684 - f1_score: 0.9136 - val_loss: 0.5608 - val_accuracy: 0.7763 - val_precision: 0.7763 - val_recall: 0.7763 - val_auc: 0.8605 - val_f1_score: 0.7752
# Epoch 43/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.2144 - accuracy: 0.9154 - precision: 0.9154 - recall: 0.9154 - auc: 0.9681 - f1_score: 0.9081 - val_loss: 0.1651 - val_accuracy: 0.9390 - val_precision: 0.9390 - val_recall: 0.9390 - val_auc: 0.9823 - val_f1_score: 0.9353
# Epoch 44/500
# 438/438 [==============================] - 11s 24ms/step - loss: 0.2031 - accuracy: 0.9224 - precision: 0.9224 - recall: 0.9224 - auc: 0.9714 - f1_score: 0.9158 - val_loss: 0.2685 - val_accuracy: 0.8597 - val_precision: 0.8597 - val_recall: 0.8597 - val_auc: 0.9521 - val_f1_score: 0.8570
# Epoch 45/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.2050 - accuracy: 0.9227 - precision: 0.9227 - recall: 0.9227 - auc: 0.9702 - f1_score: 0.9162 - val_loss: 0.2115 - val_accuracy: 0.9037 - val_precision: 0.9037 - val_recall: 0.9037 - val_auc: 0.9741 - val_f1_score: 0.9002
# Epoch 46/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1910 - accuracy: 0.9277 - precision: 0.9277 - recall: 0.9277 - auc: 0.9732 - f1_score: 0.9217 - val_loss: 0.3303 - val_accuracy: 0.8457 - val_precision: 0.8457 - val_recall: 0.8457 - val_auc: 0.9367 - val_f1_score: 0.8433
# Epoch 47/500
# 438/438 [==============================] - 10s 22ms/step - loss: 0.1956 - accuracy: 0.9274 - precision: 0.9274 - recall: 0.9274 - auc: 0.9731 - f1_score: 0.9214 - val_loss: 0.1157 - val_accuracy: 0.9503 - val_precision: 0.9503 - val_recall: 0.9503 - val_auc: 0.9915 - val_f1_score: 0.9453
# Epoch 48/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1899 - accuracy: 0.9299 - precision: 0.9299 - recall: 0.9299 - auc: 0.9729 - f1_score: 0.9240 - val_loss: 0.1597 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9861 - val_f1_score: 0.9253
# Epoch 49/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.1877 - accuracy: 0.9340 - precision: 0.9340 - recall: 0.9340 - auc: 0.9722 - f1_score: 0.9283 - val_loss: 0.2757 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9559 - val_f1_score: 0.8752
# Epoch 50/500
# 438/438 [==============================] - 9s 21ms/step - loss: 0.1861 - accuracy: 0.9356 - precision: 0.9356 - recall: 0.9356 - auc: 0.9735 - f1_score: 0.9301 - val_loss: 0.1473 - val_accuracy: 0.9347 - val_precision: 0.9347 - val_recall: 0.9347 - val_auc: 0.9866 - val_f1_score: 0.9271
# Epoch 51/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1841 - accuracy: 0.9324 - precision: 0.9324 - recall: 0.9324 - auc: 0.9744 - f1_score: 0.9267 - val_loss: 0.1114 - val_accuracy: 0.9543 - val_precision: 0.9543 - val_recall: 0.9543 - val_auc: 0.9920 - val_f1_score: 0.9498
# Epoch 52/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1592 - accuracy: 0.9426 - precision: 0.9426 - recall: 0.9426 - auc: 0.9806 - f1_score: 0.9378 - val_loss: 0.3260 - val_accuracy: 0.8587 - val_precision: 0.8587 - val_recall: 0.8587 - val_auc: 0.9356 - val_f1_score: 0.8560
# Epoch 53/500
# 438/438 [==============================] - 9s 21ms/step - loss: 0.1899 - accuracy: 0.9340 - precision: 0.9340 - recall: 0.9340 - auc: 0.9735 - f1_score: 0.9283 - val_loss: 0.1486 - val_accuracy: 0.9333 - val_precision: 0.9333 - val_recall: 0.9333 - val_auc: 0.9873 - val_f1_score: 0.9255
# Epoch 54/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1715 - accuracy: 0.9397 - precision: 0.9397 - recall: 0.9397 - auc: 0.9780 - f1_score: 0.9345 - val_loss: 0.2446 - val_accuracy: 0.9023 - val_precision: 0.9023 - val_recall: 0.9023 - val_auc: 0.9545 - val_f1_score: 0.8990
# Epoch 55/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.1738 - accuracy: 0.9369 - precision: 0.9369 - recall: 0.9369 - auc: 0.9776 - f1_score: 0.9315 - val_loss: 0.9144 - val_accuracy: 0.7097 - val_precision: 0.7097 - val_recall: 0.7097 - val_auc: 0.8232 - val_f1_score: 0.5726
# Epoch 56/500
# 438/438 [==============================] - 10s 22ms/step - loss: 0.1542 - accuracy: 0.9460 - precision: 0.9460 - recall: 0.9460 - auc: 0.9808 - f1_score: 0.9415 - val_loss: 0.1969 - val_accuracy: 0.9210 - val_precision: 0.9210 - val_recall: 0.9210 - val_auc: 0.9690 - val_f1_score: 0.9175
# Epoch 57/500
# 438/438 [==============================] - 11s 26ms/step - loss: 0.1665 - accuracy: 0.9450 - precision: 0.9450 - recall: 0.9450 - auc: 0.9789 - f1_score: 0.9404 - val_loss: 0.3553 - val_accuracy: 0.8483 - val_precision: 0.8483 - val_recall: 0.8483 - val_auc: 0.9295 - val_f1_score: 0.8455
# Epoch 58/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1685 - accuracy: 0.9407 - precision: 0.9407 - recall: 0.9407 - auc: 0.9781 - f1_score: 0.9356 - val_loss: 0.2127 - val_accuracy: 0.9120 - val_precision: 0.9120 - val_recall: 0.9120 - val_auc: 0.9740 - val_f1_score: 0.9084
# Epoch 59/500
# 438/438 [==============================] - 11s 24ms/step - loss: 0.1573 - accuracy: 0.9440 - precision: 0.9440 - recall: 0.9440 - auc: 0.9803 - f1_score: 0.9393 - val_loss: 0.1360 - val_accuracy: 0.9447 - val_precision: 0.9447 - val_recall: 0.9447 - val_auc: 0.9856 - val_f1_score: 0.9414
# Epoch 60/500
# 438/438 [==============================] - 11s 24ms/step - loss: 0.1550 - accuracy: 0.9459 - precision: 0.9459 - recall: 0.9459 - auc: 0.9814 - f1_score: 0.9413 - val_loss: 0.5408 - val_accuracy: 0.7620 - val_precision: 0.7620 - val_recall: 0.7620 - val_auc: 0.8551 - val_f1_score: 0.7616
# Epoch 61/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1605 - accuracy: 0.9479 - precision: 0.9479 - recall: 0.9479 - auc: 0.9795 - f1_score: 0.9433 - val_loss: 0.1719 - val_accuracy: 0.9217 - val_precision: 0.9217 - val_recall: 0.9217 - val_auc: 0.9765 - val_f1_score: 0.9111
# Epoch 62/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1415 - accuracy: 0.9527 - precision: 0.9527 - recall: 0.9527 - auc: 0.9842 - f1_score: 0.9487 - val_loss: 0.1067 - val_accuracy: 0.9593 - val_precision: 0.9593 - val_recall: 0.9593 - val_auc: 0.9917 - val_f1_score: 0.9564
# Epoch 63/500
# 438/438 [==============================] - 10s 24ms/step - loss: 0.1345 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524 - auc: 0.9839 - f1_score: 0.9485 - val_loss: 0.1928 - val_accuracy: 0.9200 - val_precision: 0.9200 - val_recall: 0.9200 - val_auc: 0.9712 - val_f1_score: 0.9093
# Epoch 64/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.1443 - accuracy: 0.9533 - precision: 0.9533 - recall: 0.9533 - auc: 0.9825 - f1_score: 0.9494 - val_loss: 0.1736 - val_accuracy: 0.9350 - val_precision: 0.9350 - val_recall: 0.9350 - val_auc: 0.9844 - val_f1_score: 0.9307
# Epoch 65/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.1408 - accuracy: 0.9514 - precision: 0.9514 - recall: 0.9514 - auc: 0.9832 - f1_score: 0.9474 - val_loss: 2.9590 - val_accuracy: 0.7880 - val_precision: 0.7880 - val_recall: 0.7880 - val_auc: 0.8131 - val_f1_score: 0.7805
# Epoch 66/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.1493 - accuracy: 0.9470 - precision: 0.9470 - recall: 0.9470 - auc: 0.9828 - f1_score: 0.9426 - val_loss: 0.2291 - val_accuracy: 0.9080 - val_precision: 0.9080 - val_recall: 0.9080 - val_auc: 0.9617 - val_f1_score: 0.9047
# Epoch 67/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.1441 - accuracy: 0.9473 - precision: 0.9473 - recall: 0.9473 - auc: 0.9838 - f1_score: 0.9428 - val_loss: 0.0981 - val_accuracy: 0.9603 - val_precision: 0.9603 - val_recall: 0.9603 - val_auc: 0.9929 - val_f1_score: 0.9564
# Epoch 68/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.1329 - accuracy: 0.9544 - precision: 0.9544 - recall: 0.9544 - auc: 0.9850 - f1_score: 0.9505 - val_loss: 0.1534 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9776 - val_f1_score: 0.9242
# Epoch 69/500
# 438/438 [==============================] - 12s 26ms/step - loss: 0.1460 - accuracy: 0.9496 - precision: 0.9496 - recall: 0.9496 - auc: 0.9831 - f1_score: 0.9455 - val_loss: 0.1359 - val_accuracy: 0.9423 - val_precision: 0.9423 - val_recall: 0.9423 - val_auc: 0.9876 - val_f1_score: 0.9360
# Epoch 70/500
# 438/438 [==============================] - 10s 22ms/step - loss: 0.1137 - accuracy: 0.9607 - precision: 0.9607 - recall: 0.9607 - auc: 0.9890 - f1_score: 0.9574 - val_loss: 0.1239 - val_accuracy: 0.9463 - val_precision: 0.9463 - val_recall: 0.9463 - val_auc: 0.9888 - val_f1_score: 0.9415
# Epoch 71/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1277 - accuracy: 0.9584 - precision: 0.9584 - recall: 0.9584 - auc: 0.9873 - f1_score: 0.9549 - val_loss: 0.1238 - val_accuracy: 0.9513 - val_precision: 0.9513 - val_recall: 0.9513 - val_auc: 0.9876 - val_f1_score: 0.9480
# Epoch 72/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.1188 - accuracy: 0.9603 - precision: 0.9603 - recall: 0.9603 - auc: 0.9881 - f1_score: 0.9569 - val_loss: 0.1215 - val_accuracy: 0.9533 - val_precision: 0.9533 - val_recall: 0.9533 - val_auc: 0.9833 - val_f1_score: 0.9492
# Epoch 73/500
# 438/438 [==============================] - 9s 22ms/step - loss: 0.1548 - accuracy: 0.9527 - precision: 0.9527 - recall: 0.9527 - auc: 0.9829 - f1_score: 0.9486 - val_loss: 0.1305 - val_accuracy: 0.9447 - val_precision: 0.9447 - val_recall: 0.9447 - val_auc: 0.9846 - val_f1_score: 0.9391
# Epoch 74/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.1292 - accuracy: 0.9544 - precision: 0.9544 - recall: 0.9544 - auc: 0.9867 - f1_score: 0.9506 - val_loss: 0.3188 - val_accuracy: 0.8733 - val_precision: 0.8733 - val_recall: 0.8733 - val_auc: 0.9332 - val_f1_score: 0.8702
# Epoch 75/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.1409 - accuracy: 0.9551 - precision: 0.9551 - recall: 0.9551 - auc: 0.9833 - f1_score: 0.9514 - val_loss: 0.1802 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9756 - val_f1_score: 0.9254
# Epoch 76/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.1256 - accuracy: 0.9586 - precision: 0.9586 - recall: 0.9586 - auc: 0.9864 - f1_score: 0.9550 - val_loss: 0.2655 - val_accuracy: 0.8980 - val_precision: 0.8980 - val_recall: 0.8980 - val_auc: 0.9485 - val_f1_score: 0.8812
# Epoch 77/500
# 438/438 [==============================] - 11s 24ms/step - loss: 0.1116 - accuracy: 0.9660 - precision: 0.9660 - recall: 0.9660 - auc: 0.9890 - f1_score: 0.9631 - val_loss: 0.1176 - val_accuracy: 0.9563 - val_precision: 0.9563 - val_recall: 0.9563 - val_auc: 0.9864 - val_f1_score: 0.9530
# Epoch 78/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.1080 - accuracy: 0.9646 - precision: 0.9646 - recall: 0.9646 - auc: 0.9881 - f1_score: 0.9616 - val_loss: 0.1221 - val_accuracy: 0.9510 - val_precision: 0.9510 - val_recall: 0.9510 - val_auc: 0.9848 - val_f1_score: 0.9463
# Epoch 79/500
# 438/438 [==============================] - 12s 26ms/step - loss: 0.1086 - accuracy: 0.9633 - precision: 0.9633 - recall: 0.9633 - auc: 0.9887 - f1_score: 0.9603 - val_loss: 0.2984 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9412 - val_f1_score: 0.8784
# Epoch 80/500
# 438/438 [==============================] - 10s 22ms/step - loss: 0.1325 - accuracy: 0.9570 - precision: 0.9570 - recall: 0.9570 - auc: 0.9846 - f1_score: 0.9535 - val_loss: 0.2265 - val_accuracy: 0.9117 - val_precision: 0.9117 - val_recall: 0.9117 - val_auc: 0.9638 - val_f1_score: 0.8989
# Epoch 81/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1002 - accuracy: 0.9654 - precision: 0.9654 - recall: 0.9654 - auc: 0.9896 - f1_score: 0.9626 - val_loss: 0.0929 - val_accuracy: 0.9627 - val_precision: 0.9627 - val_recall: 0.9627 - val_auc: 0.9908 - val_f1_score: 0.9595
# Epoch 82/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.1235 - accuracy: 0.9579 - precision: 0.9579 - recall: 0.9579 - auc: 0.9859 - f1_score: 0.9544 - val_loss: 0.1593 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9834 - val_f1_score: 0.9428
# Epoch 83/500
# 438/438 [==============================] - 9s 22ms/step - loss: 0.1307 - accuracy: 0.9561 - precision: 0.9561 - recall: 0.9561 - auc: 0.9858 - f1_score: 0.9526 - val_loss: 0.1941 - val_accuracy: 0.9193 - val_precision: 0.9193 - val_recall: 0.9193 - val_auc: 0.9733 - val_f1_score: 0.9079
# Epoch 84/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.1235 - accuracy: 0.9610 - precision: 0.9610 - recall: 0.9610 - auc: 0.9870 - f1_score: 0.9577 - val_loss: 0.1396 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9885 - val_f1_score: 0.9454
# Epoch 85/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1475 - accuracy: 0.9489 - precision: 0.9489 - recall: 0.9489 - auc: 0.9830 - f1_score: 0.9447 - val_loss: 0.1502 - val_accuracy: 0.9413 - val_precision: 0.9413 - val_recall: 0.9413 - val_auc: 0.9769 - val_f1_score: 0.9347
# Epoch 86/500
# 438/438 [==============================] - 9s 21ms/step - loss: 0.1207 - accuracy: 0.9590 - precision: 0.9590 - recall: 0.9590 - auc: 0.9874 - f1_score: 0.9557 - val_loss: 0.1634 - val_accuracy: 0.9257 - val_precision: 0.9257 - val_recall: 0.9257 - val_auc: 0.9838 - val_f1_score: 0.9223
# Epoch 87/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1014 - accuracy: 0.9644 - precision: 0.9644 - recall: 0.9644 - auc: 0.9900 - f1_score: 0.9614 - val_loss: 0.1986 - val_accuracy: 0.9323 - val_precision: 0.9323 - val_recall: 0.9323 - val_auc: 0.9640 - val_f1_score: 0.9289
# Epoch 88/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.0866 - accuracy: 0.9694 - precision: 0.9694 - recall: 0.9694 - auc: 0.9920 - f1_score: 0.9669 - val_loss: 0.1255 - val_accuracy: 0.9547 - val_precision: 0.9547 - val_recall: 0.9547 - val_auc: 0.9810 - val_f1_score: 0.9514
# Epoch 89/500
# 438/438 [==============================] - 11s 26ms/step - loss: 0.0961 - accuracy: 0.9673 - precision: 0.9673 - recall: 0.9673 - auc: 0.9911 - f1_score: 0.9646 - val_loss: 0.2328 - val_accuracy: 0.9327 - val_precision: 0.9327 - val_recall: 0.9327 - val_auc: 0.9730 - val_f1_score: 0.9245
# Epoch 90/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.1028 - accuracy: 0.9640 - precision: 0.9640 - recall: 0.9640 - auc: 0.9897 - f1_score: 0.9610 - val_loss: 0.1178 - val_accuracy: 0.9487 - val_precision: 0.9487 - val_recall: 0.9487 - val_auc: 0.9871 - val_f1_score: 0.9454
# Epoch 91/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0978 - accuracy: 0.9671 - precision: 0.9671 - recall: 0.9671 - auc: 0.9905 - f1_score: 0.9644 - val_loss: 0.1661 - val_accuracy: 0.9343 - val_precision: 0.9343 - val_recall: 0.9343 - val_auc: 0.9750 - val_f1_score: 0.9310
# Epoch 92/500
# 438/438 [==============================] - 12s 26ms/step - loss: 0.1085 - accuracy: 0.9667 - precision: 0.9667 - recall: 0.9667 - auc: 0.9881 - f1_score: 0.9640 - val_loss: 0.4583 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9755 - val_f1_score: 0.9238
# Epoch 93/500
# 438/438 [==============================] - 10s 23ms/step - loss: 0.0972 - accuracy: 0.9641 - precision: 0.9641 - recall: 0.9641 - auc: 0.9897 - f1_score: 0.9612 - val_loss: 0.1123 - val_accuracy: 0.9583 - val_precision: 0.9583 - val_recall: 0.9583 - val_auc: 0.9880 - val_f1_score: 0.9556
# Epoch 94/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0953 - accuracy: 0.9676 - precision: 0.9676 - recall: 0.9676 - auc: 0.9910 - f1_score: 0.9649 - val_loss: 0.1072 - val_accuracy: 0.9557 - val_precision: 0.9557 - val_recall: 0.9557 - val_auc: 0.9865 - val_f1_score: 0.9512
# Epoch 95/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.1170 - accuracy: 0.9616 - precision: 0.9616 - recall: 0.9616 - auc: 0.9873 - f1_score: 0.9584 - val_loss: 0.1200 - val_accuracy: 0.9523 - val_precision: 0.9523 - val_recall: 0.9523 - val_auc: 0.9868 - val_f1_score: 0.9487
# Epoch 96/500
# 438/438 [==============================] - 10s 22ms/step - loss: 0.0936 - accuracy: 0.9703 - precision: 0.9703 - recall: 0.9703 - auc: 0.9902 - f1_score: 0.9679 - val_loss: 0.0874 - val_accuracy: 0.9663 - val_precision: 0.9663 - val_recall: 0.9663 - val_auc: 0.9896 - val_f1_score: 0.9636
# Epoch 97/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1142 - accuracy: 0.9659 - precision: 0.9659 - recall: 0.9659 - auc: 0.9876 - f1_score: 0.9631 - val_loss: 0.2355 - val_accuracy: 0.9127 - val_precision: 0.9127 - val_recall: 0.9127 - val_auc: 0.9558 - val_f1_score: 0.9005
# Epoch 98/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1072 - accuracy: 0.9657 - precision: 0.9657 - recall: 0.9657 - auc: 0.9891 - f1_score: 0.9629 - val_loss: 0.8485 - val_accuracy: 0.7460 - val_precision: 0.7460 - val_recall: 0.7460 - val_auc: 0.7832 - val_f1_score: 0.7457
# Epoch 99/500
# 438/438 [==============================] - 10s 22ms/step - loss: 0.1457 - accuracy: 0.9490 - precision: 0.9490 - recall: 0.9490 - auc: 0.9833 - f1_score: 0.9447 - val_loss: 0.0979 - val_accuracy: 0.9603 - val_precision: 0.9603 - val_recall: 0.9603 - val_auc: 0.9924 - val_f1_score: 0.9572
# Epoch 100/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1077 - accuracy: 0.9636 - precision: 0.9636 - recall: 0.9636 - auc: 0.9891 - f1_score: 0.9606 - val_loss: 0.2598 - val_accuracy: 0.8997 - val_precision: 0.8997 - val_recall: 0.8997 - val_auc: 0.9496 - val_f1_score: 0.8964
# Epoch 101/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0915 - accuracy: 0.9677 - precision: 0.9677 - recall: 0.9677 - auc: 0.9907 - f1_score: 0.9651 - val_loss: 0.0909 - val_accuracy: 0.9647 - val_precision: 0.9647 - val_recall: 0.9647 - val_auc: 0.9906 - val_f1_score: 0.9618
# Epoch 102/500
# 438/438 [==============================] - 10s 23ms/step - loss: 0.0643 - accuracy: 0.9783 - precision: 0.9783 - recall: 0.9783 - auc: 0.9940 - f1_score: 0.9765 - val_loss: 0.2974 - val_accuracy: 0.9130 - val_precision: 0.9130 - val_recall: 0.9130 - val_auc: 0.9563 - val_f1_score: 0.9001
# Epoch 103/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.0968 - accuracy: 0.9694 - precision: 0.9694 - recall: 0.9694 - auc: 0.9894 - f1_score: 0.9669 - val_loss: 0.2874 - val_accuracy: 0.8947 - val_precision: 0.8947 - val_recall: 0.8947 - val_auc: 0.9408 - val_f1_score: 0.8914
# Epoch 104/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0927 - accuracy: 0.9700 - precision: 0.9700 - recall: 0.9700 - auc: 0.9912 - f1_score: 0.9675 - val_loss: 0.9486 - val_accuracy: 0.8210 - val_precision: 0.8210 - val_recall: 0.8210 - val_auc: 0.8734 - val_f1_score: 0.7746
# Epoch 105/500
# 438/438 [==============================] - 11s 26ms/step - loss: 0.0996 - accuracy: 0.9661 - precision: 0.9661 - recall: 0.9661 - auc: 0.9895 - f1_score: 0.9633 - val_loss: 0.1700 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9705 - val_f1_score: 0.9208
# Epoch 106/500
# 438/438 [==============================] - 10s 24ms/step - loss: 0.0855 - accuracy: 0.9714 - precision: 0.9714 - recall: 0.9714 - auc: 0.9915 - f1_score: 0.9691 - val_loss: 0.2105 - val_accuracy: 0.9237 - val_precision: 0.9237 - val_recall: 0.9237 - val_auc: 0.9584 - val_f1_score: 0.9192
# Epoch 107/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.1059 - accuracy: 0.9637 - precision: 0.9637 - recall: 0.9637 - auc: 0.9890 - f1_score: 0.9607 - val_loss: 0.2076 - val_accuracy: 0.9330 - val_precision: 0.9330 - val_recall: 0.9330 - val_auc: 0.9625 - val_f1_score: 0.9293
# Epoch 108/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.0888 - accuracy: 0.9713 - precision: 0.9713 - recall: 0.9713 - auc: 0.9914 - f1_score: 0.9690 - val_loss: 0.1241 - val_accuracy: 0.9507 - val_precision: 0.9507 - val_recall: 0.9507 - val_auc: 0.9820 - val_f1_score: 0.9452
# Epoch 109/500
# 438/438 [==============================] - 10s 22ms/step - loss: 0.1021 - accuracy: 0.9677 - precision: 0.9677 - recall: 0.9677 - auc: 0.9897 - f1_score: 0.9651 - val_loss: 0.3655 - val_accuracy: 0.8857 - val_precision: 0.8857 - val_recall: 0.8857 - val_auc: 0.9223 - val_f1_score: 0.8653
# Epoch 110/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.1022 - accuracy: 0.9666 - precision: 0.9666 - recall: 0.9666 - auc: 0.9880 - f1_score: 0.9639 - val_loss: 0.1223 - val_accuracy: 0.9490 - val_precision: 0.9490 - val_recall: 0.9490 - val_auc: 0.9833 - val_f1_score: 0.9436
# Epoch 111/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.0803 - accuracy: 0.9724 - precision: 0.9724 - recall: 0.9724 - auc: 0.9924 - f1_score: 0.9702 - val_loss: 0.0966 - val_accuracy: 0.9623 - val_precision: 0.9623 - val_recall: 0.9623 - val_auc: 0.9896 - val_f1_score: 0.9591
# Epoch 112/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.0882 - accuracy: 0.9699 - precision: 0.9699 - recall: 0.9699 - auc: 0.9906 - f1_score: 0.9674 - val_loss: 0.2905 - val_accuracy: 0.8977 - val_precision: 0.8977 - val_recall: 0.8977 - val_auc: 0.9392 - val_f1_score: 0.8944
# Epoch 113/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.0977 - accuracy: 0.9676 - precision: 0.9676 - recall: 0.9676 - auc: 0.9906 - f1_score: 0.9649 - val_loss: 0.0929 - val_accuracy: 0.9613 - val_precision: 0.9613 - val_recall: 0.9613 - val_auc: 0.9898 - val_f1_score: 0.9577
# Epoch 114/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0791 - accuracy: 0.9761 - precision: 0.9761 - recall: 0.9761 - auc: 0.9921 - f1_score: 0.9742 - val_loss: 0.1477 - val_accuracy: 0.9523 - val_precision: 0.9523 - val_recall: 0.9523 - val_auc: 0.9754 - val_f1_score: 0.9493
# Epoch 115/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.0958 - accuracy: 0.9707 - precision: 0.9707 - recall: 0.9707 - auc: 0.9899 - f1_score: 0.9683 - val_loss: 0.1024 - val_accuracy: 0.9573 - val_precision: 0.9573 - val_recall: 0.9573 - val_auc: 0.9900 - val_f1_score: 0.9538
# Epoch 116/500
# 438/438 [==============================] - 10s 22ms/step - loss: 0.0896 - accuracy: 0.9706 - precision: 0.9706 - recall: 0.9706 - auc: 0.9896 - f1_score: 0.9681 - val_loss: 0.1422 - val_accuracy: 0.9423 - val_precision: 0.9423 - val_recall: 0.9423 - val_auc: 0.9789 - val_f1_score: 0.9364
# Epoch 117/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0716 - accuracy: 0.9776 - precision: 0.9776 - recall: 0.9776 - auc: 0.9925 - f1_score: 0.9757 - val_loss: 0.1131 - val_accuracy: 0.9633 - val_precision: 0.9633 - val_recall: 0.9633 - val_auc: 0.9846 - val_f1_score: 0.9608
# Epoch 118/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.0851 - accuracy: 0.9751 - precision: 0.9751 - recall: 0.9751 - auc: 0.9917 - f1_score: 0.9731 - val_loss: 0.2956 - val_accuracy: 0.9097 - val_precision: 0.9097 - val_recall: 0.9097 - val_auc: 0.9545 - val_f1_score: 0.8960
# Epoch 119/500
# 438/438 [==============================] - 10s 22ms/step - loss: 0.0891 - accuracy: 0.9740 - precision: 0.9740 - recall: 0.9740 - auc: 0.9916 - f1_score: 0.9718 - val_loss: 0.1249 - val_accuracy: 0.9523 - val_precision: 0.9523 - val_recall: 0.9523 - val_auc: 0.9806 - val_f1_score: 0.9487
# Epoch 120/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.0874 - accuracy: 0.9739 - precision: 0.9739 - recall: 0.9739 - auc: 0.9908 - f1_score: 0.9717 - val_loss: 0.1773 - val_accuracy: 0.9323 - val_precision: 0.9323 - val_recall: 0.9323 - val_auc: 0.9693 - val_f1_score: 0.9291
# Epoch 121/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0789 - accuracy: 0.9751 - precision: 0.9751 - recall: 0.9751 - auc: 0.9926 - f1_score: 0.9731 - val_loss: 0.1028 - val_accuracy: 0.9623 - val_precision: 0.9623 - val_recall: 0.9623 - val_auc: 0.9849 - val_f1_score: 0.9594
# Epoch 122/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.0821 - accuracy: 0.9724 - precision: 0.9724 - recall: 0.9724 - auc: 0.9918 - f1_score: 0.9702 - val_loss: 0.1356 - val_accuracy: 0.9513 - val_precision: 0.9513 - val_recall: 0.9513 - val_auc: 0.9794 - val_f1_score: 0.9481
# Epoch 123/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.0863 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9910 - f1_score: 0.9708 - val_loss: 0.0943 - val_accuracy: 0.9643 - val_precision: 0.9643 - val_recall: 0.9643 - val_auc: 0.9889 - val_f1_score: 0.9616
# Epoch 124/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0717 - accuracy: 0.9789 - precision: 0.9789 - recall: 0.9789 - auc: 0.9924 - f1_score: 0.9771 - val_loss: 0.1745 - val_accuracy: 0.9450 - val_precision: 0.9450 - val_recall: 0.9450 - val_auc: 0.9651 - val_f1_score: 0.9420
# Epoch 125/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.0959 - accuracy: 0.9684 - precision: 0.9684 - recall: 0.9684 - auc: 0.9903 - f1_score: 0.9659 - val_loss: 0.0910 - val_accuracy: 0.9650 - val_precision: 0.9650 - val_recall: 0.9650 - val_auc: 0.9889 - val_f1_score: 0.9622
# Epoch 126/500
# 438/438 [==============================] - 10s 23ms/step - loss: 0.0711 - accuracy: 0.9780 - precision: 0.9780 - recall: 0.9780 - auc: 0.9934 - f1_score: 0.9761 - val_loss: 0.3000 - val_accuracy: 0.9063 - val_precision: 0.9063 - val_recall: 0.9063 - val_auc: 0.9345 - val_f1_score: 0.9029
# Epoch 127/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0748 - accuracy: 0.9786 - precision: 0.9786 - recall: 0.9786 - auc: 0.9922 - f1_score: 0.9768 - val_loss: 0.2072 - val_accuracy: 0.9247 - val_precision: 0.9247 - val_recall: 0.9247 - val_auc: 0.9599 - val_f1_score: 0.9209
# Epoch 128/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.0862 - accuracy: 0.9746 - precision: 0.9746 - recall: 0.9746 - auc: 0.9903 - f1_score: 0.9725 - val_loss: 0.1234 - val_accuracy: 0.9420 - val_precision: 0.9420 - val_recall: 0.9420 - val_auc: 0.9839 - val_f1_score: 0.9353
# Epoch 129/500
# 438/438 [==============================] - 10s 23ms/step - loss: 0.0637 - accuracy: 0.9814 - precision: 0.9814 - recall: 0.9814 - auc: 0.9948 - f1_score: 0.9799 - val_loss: 0.1377 - val_accuracy: 0.9543 - val_precision: 0.9543 - val_recall: 0.9543 - val_auc: 0.9755 - val_f1_score: 0.9510
# Epoch 130/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0712 - accuracy: 0.9784 - precision: 0.9784 - recall: 0.9784 - auc: 0.9929 - f1_score: 0.9766 - val_loss: 0.0938 - val_accuracy: 0.9623 - val_precision: 0.9623 - val_recall: 0.9623 - val_auc: 0.9902 - val_f1_score: 0.9589
# Epoch 131/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0651 - accuracy: 0.9801 - precision: 0.9801 - recall: 0.9801 - auc: 0.9943 - f1_score: 0.9785 - val_loss: 0.1244 - val_accuracy: 0.9563 - val_precision: 0.9563 - val_recall: 0.9563 - val_auc: 0.9786 - val_f1_score: 0.9529
# Epoch 132/500
# 438/438 [==============================] - 10s 22ms/step - loss: 0.0785 - accuracy: 0.9736 - precision: 0.9736 - recall: 0.9736 - auc: 0.9919 - f1_score: 0.9714 - val_loss: 0.1367 - val_accuracy: 0.9513 - val_precision: 0.9513 - val_recall: 0.9513 - val_auc: 0.9792 - val_f1_score: 0.9466
# Epoch 133/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0957 - accuracy: 0.9721 - precision: 0.9721 - recall: 0.9721 - auc: 0.9894 - f1_score: 0.9698 - val_loss: 0.1208 - val_accuracy: 0.9613 - val_precision: 0.9613 - val_recall: 0.9613 - val_auc: 0.9800 - val_f1_score: 0.9588
# Epoch 134/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0698 - accuracy: 0.9774 - precision: 0.9774 - recall: 0.9774 - auc: 0.9931 - f1_score: 0.9756 - val_loss: 0.1165 - val_accuracy: 0.9560 - val_precision: 0.9560 - val_recall: 0.9560 - val_auc: 0.9820 - val_f1_score: 0.9516
# Epoch 135/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.0525 - accuracy: 0.9830 - precision: 0.9830 - recall: 0.9830 - auc: 0.9951 - f1_score: 0.9816 - val_loss: 0.2078 - val_accuracy: 0.9437 - val_precision: 0.9437 - val_recall: 0.9437 - val_auc: 0.9630 - val_f1_score: 0.9406
# Epoch 136/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.0810 - accuracy: 0.9764 - precision: 0.9764 - recall: 0.9764 - auc: 0.9924 - f1_score: 0.9745 - val_loss: 1.1276 - val_accuracy: 0.6507 - val_precision: 0.6507 - val_recall: 0.6507 - val_auc: 0.6639 - val_f1_score: 0.6488
# Epoch 137/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0902 - accuracy: 0.9714 - precision: 0.9714 - recall: 0.9714 - auc: 0.9897 - f1_score: 0.9691 - val_loss: 0.0997 - val_accuracy: 0.9580 - val_precision: 0.9580 - val_recall: 0.9580 - val_auc: 0.9878 - val_f1_score: 0.9543
# Epoch 138/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.0687 - accuracy: 0.9804 - precision: 0.9804 - recall: 0.9804 - auc: 0.9939 - f1_score: 0.9788 - val_loss: 0.1321 - val_accuracy: 0.9547 - val_precision: 0.9547 - val_recall: 0.9547 - val_auc: 0.9828 - val_f1_score: 0.9501
# Epoch 139/500
# 438/438 [==============================] - 10s 23ms/step - loss: 0.0674 - accuracy: 0.9817 - precision: 0.9817 - recall: 0.9817 - auc: 0.9936 - f1_score: 0.9802 - val_loss: 0.1875 - val_accuracy: 0.9420 - val_precision: 0.9420 - val_recall: 0.9420 - val_auc: 0.9712 - val_f1_score: 0.9356
# Epoch 140/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.0538 - accuracy: 0.9821 - precision: 0.9821 - recall: 0.9821 - auc: 0.9947 - f1_score: 0.9806 - val_loss: 0.1043 - val_accuracy: 0.9607 - val_precision: 0.9607 - val_recall: 0.9607 - val_auc: 0.9865 - val_f1_score: 0.9573
# Epoch 141/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0820 - accuracy: 0.9746 - precision: 0.9746 - recall: 0.9746 - auc: 0.9913 - f1_score: 0.9725 - val_loss: 0.1413 - val_accuracy: 0.9500 - val_precision: 0.9500 - val_recall: 0.9500 - val_auc: 0.9789 - val_f1_score: 0.9455
# Epoch 142/500
# 438/438 [==============================] - 10s 22ms/step - loss: 0.0818 - accuracy: 0.9750 - precision: 0.9750 - recall: 0.9750 - auc: 0.9909 - f1_score: 0.9729 - val_loss: 0.0872 - val_accuracy: 0.9627 - val_precision: 0.9627 - val_recall: 0.9627 - val_auc: 0.9907 - val_f1_score: 0.9593
# Epoch 143/500
# 438/438 [==============================] - 12s 29ms/step - loss: 0.0644 - accuracy: 0.9803 - precision: 0.9803 - recall: 0.9803 - auc: 0.9935 - f1_score: 0.9787 - val_loss: 0.1003 - val_accuracy: 0.9640 - val_precision: 0.9640 - val_recall: 0.9640 - val_auc: 0.9869 - val_f1_score: 0.9609
# Epoch 144/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0777 - accuracy: 0.9750 - precision: 0.9750 - recall: 0.9750 - auc: 0.9928 - f1_score: 0.9730 - val_loss: 0.1072 - val_accuracy: 0.9593 - val_precision: 0.9593 - val_recall: 0.9593 - val_auc: 0.9833 - val_f1_score: 0.9560
# Epoch 145/500
# 438/438 [==============================] - 11s 26ms/step - loss: 0.0522 - accuracy: 0.9827 - precision: 0.9827 - recall: 0.9827 - auc: 0.9959 - f1_score: 0.9813 - val_loss: 0.1097 - val_accuracy: 0.9633 - val_precision: 0.9633 - val_recall: 0.9633 - val_auc: 0.9854 - val_f1_score: 0.9605
# Epoch 146/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.0717 - accuracy: 0.9779 - precision: 0.9779 - recall: 0.9779 - auc: 0.9925 - f1_score: 0.9760 - val_loss: 0.1126 - val_accuracy: 0.9567 - val_precision: 0.9567 - val_recall: 0.9567 - val_auc: 0.9841 - val_f1_score: 0.9530
# Epoch 147/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.0576 - accuracy: 0.9821 - precision: 0.9821 - recall: 0.9821 - auc: 0.9953 - f1_score: 0.9807 - val_loss: 0.0902 - val_accuracy: 0.9660 - val_precision: 0.9660 - val_recall: 0.9660 - val_auc: 0.9896 - val_f1_score: 0.9635
# Epoch 148/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.0521 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9843 - auc: 0.9959 - f1_score: 0.9830 - val_loss: 0.1158 - val_accuracy: 0.9587 - val_precision: 0.9587 - val_recall: 0.9587 - val_auc: 0.9815 - val_f1_score: 0.9545
# Epoch 149/500
# 438/438 [==============================] - 10s 23ms/step - loss: 0.0703 - accuracy: 0.9777 - precision: 0.9777 - recall: 0.9777 - auc: 0.9930 - f1_score: 0.9759 - val_loss: 0.3054 - val_accuracy: 0.8957 - val_precision: 0.8957 - val_recall: 0.8957 - val_auc: 0.9293 - val_f1_score: 0.8923
# Epoch 150/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.0804 - accuracy: 0.9763 - precision: 0.9763 - recall: 0.9763 - auc: 0.9925 - f1_score: 0.9743 - val_loss: 0.1420 - val_accuracy: 0.9590 - val_precision: 0.9590 - val_recall: 0.9590 - val_auc: 0.9843 - val_f1_score: 0.9555
# Epoch 151/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.0637 - accuracy: 0.9814 - precision: 0.9814 - recall: 0.9814 - auc: 0.9931 - f1_score: 0.9799 - val_loss: 0.1781 - val_accuracy: 0.9400 - val_precision: 0.9400 - val_recall: 0.9400 - val_auc: 0.9705 - val_f1_score: 0.9365
# Epoch 152/500
# 438/438 [==============================] - 10s 22ms/step - loss: 0.0893 - accuracy: 0.9716 - precision: 0.9716 - recall: 0.9716 - auc: 0.9914 - f1_score: 0.9692 - val_loss: 0.1049 - val_accuracy: 0.9623 - val_precision: 0.9623 - val_recall: 0.9623 - val_auc: 0.9839 - val_f1_score: 0.9594
# Epoch 153/500
# 438/438 [==============================] - 12s 29ms/step - loss: 0.0541 - accuracy: 0.9824 - precision: 0.9824 - recall: 0.9824 - auc: 0.9951 - f1_score: 0.9810 - val_loss: 0.1916 - val_accuracy: 0.9380 - val_precision: 0.9380 - val_recall: 0.9380 - val_auc: 0.9640 - val_f1_score: 0.9348
# Epoch 154/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0472 - accuracy: 0.9850 - precision: 0.9850 - recall: 0.9850 - auc: 0.9952 - f1_score: 0.9838 - val_loss: 0.1165 - val_accuracy: 0.9577 - val_precision: 0.9577 - val_recall: 0.9577 - val_auc: 0.9816 - val_f1_score: 0.9541
# Epoch 155/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.0637 - accuracy: 0.9806 - precision: 0.9806 - recall: 0.9806 - auc: 0.9929 - f1_score: 0.9790 - val_loss: 0.1090 - val_accuracy: 0.9587 - val_precision: 0.9587 - val_recall: 0.9587 - val_auc: 0.9837 - val_f1_score: 0.9548
# Epoch 156/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.0525 - accuracy: 0.9840 - precision: 0.9840 - recall: 0.9840 - auc: 0.9949 - f1_score: 0.9827 - val_loss: 0.1068 - val_accuracy: 0.9583 - val_precision: 0.9583 - val_recall: 0.9583 - val_auc: 0.9833 - val_f1_score: 0.9548
# Epoch 157/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0611 - accuracy: 0.9819 - precision: 0.9819 - recall: 0.9819 - auc: 0.9933 - f1_score: 0.9804 - val_loss: 0.2171 - val_accuracy: 0.9357 - val_precision: 0.9357 - val_recall: 0.9357 - val_auc: 0.9589 - val_f1_score: 0.9325
# Epoch 158/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.0552 - accuracy: 0.9839 - precision: 0.9839 - recall: 0.9839 - auc: 0.9956 - f1_score: 0.9825 - val_loss: 0.1208 - val_accuracy: 0.9570 - val_precision: 0.9570 - val_recall: 0.9570 - val_auc: 0.9816 - val_f1_score: 0.9541
# Epoch 159/500
# ...
# Epoch 247/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.0610 - accuracy: 0.9839 - precision: 0.9839 - recall: 0.9839 - auc: 0.9935 - f1_score: 0.9825 - val_loss: 0.0987 - val_accuracy: 0.9593 - val_precision: 0.9593 - val_recall: 0.9593 - val_auc: 0.9872 - val_f1_score: 0.9560
# Epoch 248/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0262 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9985 - f1_score: 0.9929 - val_loss: 0.1353 - val_accuracy: 0.9567 - val_precision: 0.9567 - val_recall: 0.9567 - val_auc: 0.9804 - val_f1_score: 0.9529
# Epoch 249/500
# 438/438 [==============================] - 10s 24ms/step - loss: 0.0361 - accuracy: 0.9903 - precision: 0.9903 - recall: 0.9903 - auc: 0.9964 - f1_score: 0.9895 - val_loss: 0.1638 - val_accuracy: 0.9493 - val_precision: 0.9493 - val_recall: 0.9493 - val_auc: 0.9786 - val_f1_score: 0.9438
# Epoch 250/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.0252 - accuracy: 0.9931 - precision: 0.9931 - recall: 0.9931 - auc: 0.9983 - f1_score: 0.9926 - val_loss: 0.1918 - val_accuracy: 0.9513 - val_precision: 0.9513 - val_recall: 0.9513 - val_auc: 0.9709 - val_f1_score: 0.9461
# Epoch 251/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.0313 - accuracy: 0.9914 - precision: 0.9914 - recall: 0.9914 - auc: 0.9965 - f1_score: 0.9907 - val_loss: 0.2411 - val_accuracy: 0.9393 - val_precision: 0.9393 - val_recall: 0.9393 - val_auc: 0.9586 - val_f1_score: 0.9363
# Epoch 252/500
# 438/438 [==============================] - 10s 23ms/step - loss: 0.0294 - accuracy: 0.9914 - precision: 0.9914 - recall: 0.9914 - auc: 0.9968 - f1_score: 0.9907 - val_loss: 0.1079 - val_accuracy: 0.9640 - val_precision: 0.9640 - val_recall: 0.9640 - val_auc: 0.9848 - val_f1_score: 0.9613
# Epoch 253/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.0406 - accuracy: 0.9876 - precision: 0.9876 - recall: 0.9876 - auc: 0.9961 - f1_score: 0.9866 - val_loss: 0.1654 - val_accuracy: 0.9533 - val_precision: 0.9533 - val_recall: 0.9533 - val_auc: 0.9726 - val_f1_score: 0.9503
# Epoch 254/500
# 438/438 [==============================] - 14s 31ms/step - loss: 0.0341 - accuracy: 0.9890 - precision: 0.9890 - recall: 0.9890 - auc: 0.9968 - f1_score: 0.9881 - val_loss: 0.1936 - val_accuracy: 0.9440 - val_precision: 0.9440 - val_recall: 0.9440 - val_auc: 0.9693 - val_f1_score: 0.9383
# Epoch 255/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.0263 - accuracy: 0.9933 - precision: 0.9933 - recall: 0.9933 - auc: 0.9977 - f1_score: 0.9927 - val_loss: 0.2033 - val_accuracy: 0.9430 - val_precision: 0.9430 - val_recall: 0.9430 - val_auc: 0.9705 - val_f1_score: 0.9369
# Epoch 256/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.0540 - accuracy: 0.9841 - precision: 0.9841 - recall: 0.9841 - auc: 0.9943 - f1_score: 0.9828 - val_loss: 0.2356 - val_accuracy: 0.9267 - val_precision: 0.9267 - val_recall: 0.9267 - val_auc: 0.9588 - val_f1_score: 0.9214
# Epoch 257/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0599 - accuracy: 0.9824 - precision: 0.9824 - recall: 0.9824 - auc: 0.9945 - f1_score: 0.9810 - val_loss: 0.1267 - val_accuracy: 0.9550 - val_precision: 0.9550 - val_recall: 0.9550 - val_auc: 0.9812 - val_f1_score: 0.9505
# Epoch 258/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0327 - accuracy: 0.9903 - precision: 0.9903 - recall: 0.9903 - auc: 0.9975 - f1_score: 0.9895 - val_loss: 0.1501 - val_accuracy: 0.9563 - val_precision: 0.9563 - val_recall: 0.9563 - val_auc: 0.9751 - val_f1_score: 0.9521
# Epoch 259/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.0327 - accuracy: 0.9913 - precision: 0.9913 - recall: 0.9913 - auc: 0.9972 - f1_score: 0.9906 - val_loss: 0.1081 - val_accuracy: 0.9663 - val_precision: 0.9663 - val_recall: 0.9663 - val_auc: 0.9834 - val_f1_score: 0.9636
# Epoch 260/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0621 - accuracy: 0.9823 - precision: 0.9823 - recall: 0.9823 - auc: 0.9933 - f1_score: 0.9808 - val_loss: 0.1158 - val_accuracy: 0.9613 - val_precision: 0.9613 - val_recall: 0.9613 - val_auc: 0.9838 - val_f1_score: 0.9579
# Epoch 261/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0368 - accuracy: 0.9870 - precision: 0.9870 - recall: 0.9870 - auc: 0.9975 - f1_score: 0.9859 - val_loss: 0.1243 - val_accuracy: 0.9593 - val_precision: 0.9593 - val_recall: 0.9593 - val_auc: 0.9801 - val_f1_score: 0.9565
# Epoch 262/500
# 438/438 [==============================] - 11s 24ms/step - loss: 0.0379 - accuracy: 0.9909 - precision: 0.9909 - recall: 0.9909 - auc: 0.9957 - f1_score: 0.9901 - val_loss: 0.2095 - val_accuracy: 0.9423 - val_precision: 0.9423 - val_recall: 0.9423 - val_auc: 0.9637 - val_f1_score: 0.9390
# Epoch 263/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0265 - accuracy: 0.9930 - precision: 0.9930 - recall: 0.9930 - auc: 0.9978 - f1_score: 0.9924 - val_loss: 0.1151 - val_accuracy: 0.9637 - val_precision: 0.9637 - val_recall: 0.9637 - val_auc: 0.9830 - val_f1_score: 0.9606
# Epoch 264/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0248 - accuracy: 0.9927 - precision: 0.9927 - recall: 0.9927 - auc: 0.9980 - f1_score: 0.9921 - val_loss: 0.1429 - val_accuracy: 0.9630 - val_precision: 0.9630 - val_recall: 0.9630 - val_auc: 0.9769 - val_f1_score: 0.9602
# Epoch 265/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.0248 - accuracy: 0.9939 - precision: 0.9939 - recall: 0.9939 - auc: 0.9973 - f1_score: 0.9934 - val_loss: 0.2500 - val_accuracy: 0.9463 - val_precision: 0.9463 - val_recall: 0.9463 - val_auc: 0.9610 - val_f1_score: 0.9431
# Epoch 266/500
# 438/438 [==============================] - 12s 26ms/step - loss: 0.0646 - accuracy: 0.9827 - precision: 0.9827 - recall: 0.9827 - auc: 0.9931 - f1_score: 0.9813 - val_loss: 0.2391 - val_accuracy: 0.9347 - val_precision: 0.9347 - val_recall: 0.9347 - val_auc: 0.9583 - val_f1_score: 0.9313
# Epoch 267/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0371 - accuracy: 0.9903 - precision: 0.9903 - recall: 0.9903 - auc: 0.9973 - f1_score: 0.9895 - val_loss: 0.1170 - val_accuracy: 0.9613 - val_precision: 0.9613 - val_recall: 0.9613 - val_auc: 0.9836 - val_f1_score: 0.9579
# Epoch 268/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0291 - accuracy: 0.9921 - precision: 0.9921 - recall: 0.9921 - auc: 0.9975 - f1_score: 0.9915 - val_loss: 0.1376 - val_accuracy: 0.9613 - val_precision: 0.9613 - val_recall: 0.9613 - val_auc: 0.9771 - val_f1_score: 0.9575
# Epoch 269/500
# 438/438 [==============================] - 11s 24ms/step - loss: 0.0583 - accuracy: 0.9849 - precision: 0.9849 - recall: 0.9849 - auc: 0.9937 - f1_score: 0.9836 - val_loss: 0.1669 - val_accuracy: 0.9443 - val_precision: 0.9443 - val_recall: 0.9443 - val_auc: 0.9714 - val_f1_score: 0.9400
# Epoch 270/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0466 - accuracy: 0.9880 - precision: 0.9880 - recall: 0.9880 - auc: 0.9954 - f1_score: 0.9870 - val_loss: 0.2615 - val_accuracy: 0.9283 - val_precision: 0.9283 - val_recall: 0.9283 - val_auc: 0.9496 - val_f1_score: 0.9249
# Epoch 271/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0430 - accuracy: 0.9867 - precision: 0.9867 - recall: 0.9867 - auc: 0.9959 - f1_score: 0.9856 - val_loss: 0.1194 - val_accuracy: 0.9603 - val_precision: 0.9603 - val_recall: 0.9603 - val_auc: 0.9823 - val_f1_score: 0.9571
# Epoch 272/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.0738 - accuracy: 0.9787 - precision: 0.9787 - recall: 0.9787 - auc: 0.9911 - f1_score: 0.9770 - val_loss: 0.1183 - val_accuracy: 0.9543 - val_precision: 0.9543 - val_recall: 0.9543 - val_auc: 0.9817 - val_f1_score: 0.9503
# Epoch 273/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.0389 - accuracy: 0.9904 - precision: 0.9904 - recall: 0.9904 - auc: 0.9965 - f1_score: 0.9896 - val_loss: 0.1056 - val_accuracy: 0.9637 - val_precision: 0.9637 - val_recall: 0.9637 - val_auc: 0.9838 - val_f1_score: 0.9604
# Epoch 274/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0266 - accuracy: 0.9930 - precision: 0.9930 - recall: 0.9930 - auc: 0.9977 - f1_score: 0.9924 - val_loss: 0.2105 - val_accuracy: 0.9507 - val_precision: 0.9507 - val_recall: 0.9507 - val_auc: 0.9736 - val_f1_score: 0.9469
# Epoch 275/500
# 438/438 [==============================] - 12s 28ms/step - loss: 0.0551 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9843 - auc: 0.9942 - f1_score: 0.9830 - val_loss: 0.2067 - val_accuracy: 0.9440 - val_precision: 0.9440 - val_recall: 0.9440 - val_auc: 0.9640 - val_f1_score: 0.9387
# Epoch 276/500
# 438/438 [==============================] - 11s 24ms/step - loss: 0.0281 - accuracy: 0.9913 - precision: 0.9913 - recall: 0.9913 - auc: 0.9980 - f1_score: 0.9906 - val_loss: 0.2605 - val_accuracy: 0.9513 - val_precision: 0.9513 - val_recall: 0.9513 - val_auc: 0.9646 - val_f1_score: 0.9468
# Epoch 277/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0440 - accuracy: 0.9876 - precision: 0.9876 - recall: 0.9876 - auc: 0.9953 - f1_score: 0.9866 - val_loss: 0.1087 - val_accuracy: 0.9623 - val_precision: 0.9623 - val_recall: 0.9623 - val_auc: 0.9846 - val_f1_score: 0.9591
# Epoch 278/500
# 438/438 [==============================] - 12s 29ms/step - loss: 0.0262 - accuracy: 0.9921 - precision: 0.9921 - recall: 0.9921 - auc: 0.9979 - f1_score: 0.9915 - val_loss: 0.1271 - val_accuracy: 0.9620 - val_precision: 0.9620 - val_recall: 0.9620 - val_auc: 0.9815 - val_f1_score: 0.9592
# Epoch 279/500
# 438/438 [==============================] - 10s 23ms/step - loss: 0.0419 - accuracy: 0.9886 - precision: 0.9886 - recall: 0.9886 - auc: 0.9964 - f1_score: 0.9876 - val_loss: 0.1416 - val_accuracy: 0.9607 - val_precision: 0.9607 - val_recall: 0.9607 - val_auc: 0.9775 - val_f1_score: 0.9579
# Epoch 280/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0298 - accuracy: 0.9910 - precision: 0.9910 - recall: 0.9910 - auc: 0.9971 - f1_score: 0.9903 - val_loss: 0.1477 - val_accuracy: 0.9590 - val_precision: 0.9590 - val_recall: 0.9590 - val_auc: 0.9778 - val_f1_score: 0.9560
# Epoch 281/500
# 438/438 [==============================] - 13s 31ms/step - loss: 0.0282 - accuracy: 0.9913 - precision: 0.9913 - recall: 0.9913 - auc: 0.9972 - f1_score: 0.9906 - val_loss: 0.1729 - val_accuracy: 0.9547 - val_precision: 0.9547 - val_recall: 0.9547 - val_auc: 0.9746 - val_f1_score: 0.9517
# Epoch 282/500
# 438/438 [==============================] - 12s 27ms/step - loss: 0.0247 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - auc: 0.9974 - f1_score: 0.9932 - val_loss: 0.1352 - val_accuracy: 0.9603 - val_precision: 0.9603 - val_recall: 0.9603 - val_auc: 0.9797 - val_f1_score: 0.9571
# Epoch 283/500
# 438/438 [==============================] - 12s 26ms/step - loss: 0.0228 - accuracy: 0.9940 - precision: 0.9940 - recall: 0.9940 - auc: 0.9983 - f1_score: 0.9935 - val_loss: 0.1896 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9710 - val_f1_score: 0.9462
# Epoch 284/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0351 - accuracy: 0.9904 - precision: 0.9904 - recall: 0.9904 - auc: 0.9968 - f1_score: 0.9896 - val_loss: 0.2253 - val_accuracy: 0.9433 - val_precision: 0.9433 - val_recall: 0.9433 - val_auc: 0.9642 - val_f1_score: 0.9366
# Epoch 285/500
# 438/438 [==============================] - 12s 29ms/step - loss: 0.0458 - accuracy: 0.9867 - precision: 0.9867 - recall: 0.9867 - auc: 0.9953 - f1_score: 0.9856 - val_loss: 0.1178 - val_accuracy: 0.9647 - val_precision: 0.9647 - val_recall: 0.9647 - val_auc: 0.9821 - val_f1_score: 0.9616
# Epoch 286/500
# 438/438 [==============================] - 11s 25ms/step - loss: 0.0338 - accuracy: 0.9907 - precision: 0.9907 - recall: 0.9907 - auc: 0.9966 - f1_score: 0.9899 - val_loss: 0.1192 - val_accuracy: 0.9580 - val_precision: 0.9580 - val_recall: 0.9580 - val_auc: 0.9844 - val_f1_score: 0.9550
# Epoch 287/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0519 - accuracy: 0.9853 - precision: 0.9853 - recall: 0.9853 - auc: 0.9941 - f1_score: 0.9841 - val_loss: 0.1146 - val_accuracy: 0.9613 - val_precision: 0.9613 - val_recall: 0.9613 - val_auc: 0.9826 - val_f1_score: 0.9581
# Epoch 288/500
# 438/438 [==============================] - 13s 31ms/step - loss: 0.0251 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9978 - f1_score: 0.9913 - val_loss: 0.1968 - val_accuracy: 0.9550 - val_precision: 0.9550 - val_recall: 0.9550 - val_auc: 0.9684 - val_f1_score: 0.9517
# Epoch 289/500
# 438/438 [==============================] - 12s 26ms/step - loss: 0.0138 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 0.9994 - f1_score: 0.9972 - val_loss: 0.1315 - val_accuracy: 0.9667 - val_precision: 0.9667 - val_recall: 0.9667 - val_auc: 0.9821 - val_f1_score: 0.9640
# Epoch 290/500
# 438/438 [==============================] - 12s 26ms/step - loss: 0.0261 - accuracy: 0.9927 - precision: 0.9927 - recall: 0.9927 - auc: 0.9974 - f1_score: 0.9921 - val_loss: 0.1427 - val_accuracy: 0.9593 - val_precision: 0.9593 - val_recall: 0.9593 - val_auc: 0.9776 - val_f1_score: 0.9558
# Epoch 291/500
# 438/438 [==============================] - 13s 31ms/step - loss: 0.0423 - accuracy: 0.9889 - precision: 0.9889 - recall: 0.9889 - auc: 0.9956 - f1_score: 0.9879 - val_loss: 0.1448 - val_accuracy: 0.9520 - val_precision: 0.9520 - val_recall: 0.9520 - val_auc: 0.9782 - val_f1_score: 0.9477
# Epoch 292/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0300 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9979 - f1_score: 0.9913 - val_loss: 0.1260 - val_accuracy: 0.9647 - val_precision: 0.9647 - val_recall: 0.9647 - val_auc: 0.9800 - val_f1_score: 0.9618
# Epoch 293/500
# 438/438 [==============================] - 10s 24ms/step - loss: 0.0372 - accuracy: 0.9901 - precision: 0.9901 - recall: 0.9901 - auc: 0.9962 - f1_score: 0.9893 - val_loss: 0.1427 - val_accuracy: 0.9520 - val_precision: 0.9520 - val_recall: 0.9520 - val_auc: 0.9754 - val_f1_score: 0.9487
# Epoch 294/500
# 438/438 [==============================] - 13s 30ms/step - loss: 0.0380 - accuracy: 0.9896 - precision: 0.9896 - recall: 0.9896 - auc: 0.9962 - f1_score: 0.9887 - val_loss: 0.1520 - val_accuracy: 0.9510 - val_precision: 0.9510 - val_recall: 0.9510 - val_auc: 0.9759 - val_f1_score: 0.9466
# Epoch 295/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.0435 - accuracy: 0.9859 - precision: 0.9859 - recall: 0.9859 - auc: 0.9954 - f1_score: 0.9847 - val_loss: 0.0987 - val_accuracy: 0.9637 - val_precision: 0.9637 - val_recall: 0.9637 - val_auc: 0.9858 - val_f1_score: 0.9607
# Epoch 296/500
# 438/438 [==============================] - 10s 24ms/step - loss: 0.0614 - accuracy: 0.9833 - precision: 0.9833 - recall: 0.9833 - auc: 0.9937 - f1_score: 0.9819 - val_loss: 0.1399 - val_accuracy: 0.9470 - val_precision: 0.9470 - val_recall: 0.9470 - val_auc: 0.9783 - val_f1_score: 0.9415
# Epoch 297/500
# 438/438 [==============================] - 13s 29ms/step - loss: 0.0336 - accuracy: 0.9917 - precision: 0.9917 - recall: 0.9917 - auc: 0.9972 - f1_score: 0.9910 - val_loss: 0.1508 - val_accuracy: 0.9587 - val_precision: 0.9587 - val_recall: 0.9587 - val_auc: 0.9756 - val_f1_score: 0.9558
# Epoch 298/500
# 438/438 [==============================] - 14s 31ms/step - loss: 0.0246 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9980 - f1_score: 0.9929 - val_loss: 0.2753 - val_accuracy: 0.9357 - val_precision: 0.9357 - val_recall: 0.9357 - val_auc: 0.9549 - val_f1_score: 0.9277

# %%
model.save('/content/drive/MyDrive/Máster UNED/TFM/Datasets/'+'uci_model_hybrid_n.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
print(model_history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'recall', 'auc', 'val_loss', 'val_accuracy', 'val_precision', 'val_recall', 'val_auc'])

# %% [markdown]
# <a id="section6"></a>
# # <font color="#004D7F" size=6> 6. Results</font>
#
# Finally, we can evaluate our hybrid model with the images created by TINTOlib in any of the ways represented below.

# %% [markdown]
# ---
# <a id="section61"></a>
# # <font color="#004D7F" size=5> 6.1. Train/Validation representation</font>

# %%
#print(model_history.history['loss'])
plt.plot(model_history.history['loss'], color = 'red', label = 'loss')
plt.plot(model_history.history['val_loss'], color = 'green', label = 'val loss')
plt.legend(loc = 'upper right')

plt.show()

# %%
plt.plot(model_history.history['accuracy'], color = 'red', label = 'accuracy')
plt.plot(model_history.history['val_accuracy'], color = 'green', label = 'val accuracy')
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# ---
# <a id="section62"></a>
# # <font color="#004D7F" size=5> 6.2. Validation/Test evaluation</font>

# %%
score_test= model.evaluate([X_val_num, X_val_img], y_val_oh)
# Out:
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0862 - accuracy: 0.9650 - precision: 0.9650 - recall: 0.9650 - auc: 0.9898 - f1_score: 0.9618
